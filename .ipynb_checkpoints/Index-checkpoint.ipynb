# %% [markdown]
# <div class = "Title">
#     <p>多様体上のデータクラウドと</p>
#     <p>パーシステントホモロジー</p>
#     <p>沖田  大河</p>
# </div>

# %% [markdown]
# <p class = "Index">目次</p>

# %% [markdown]
# <div class = NotNumber>
#     <div class = "contents">
#         <p class = "Chapter">0&emsp;&emsp;序文</p>
#         <div class ="pageNum">
#             <p>3</p>
#         </div>
#      </div>
#     <div class = "contents">
#         <p class = "Section">&emsp; &emsp;&emsp;&emsp;はじめに</p>
#         <div class ="pageNum"><p>3</p></div>
#      </div>
#     <div class = "contents">
#         <p class = "Section">&emsp; &emsp;&emsp;&emsp;謝辞</p>
#         <div class = "pageNum"><p>4</p></div>
#         </div>
# </div>

# %% [markdown]
# <div class = "contents">
#     <p class = "Chapter">ホモロジー</p>
#     <div class = "pageNum"><p>5</p></div>
# </div>
# <div class ="contents">
#     <p class = "Section"> 単体複体</p>
#     <div class="pageNum"><p>5</p></div>
# </div>
# <div class = "contents">
#     <p class = "Subsection">単体複体と多面体</p>
#      <div class="pageNum"><p>5</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">単体複体の組み合わせ構造</p>
# <div class="pageNum"><p>6</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">単体分割</p>
#  <div class="pageNum"><p>8</p></div>
#  </div>
#  <div class = "contents">
# <p class = "Subsection">脈体定理</p>
# <div class="pageNum"><p>9</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">ホモロジー群</p>
# <div class="pageNum"><p>10</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">複体のホモロジー</p>
# <div class="pageNum"><p>10</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">ホモトピー同値</p>
# <div class="pageNum"><p>13</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">誘導準同型</p>
# <div class="pageNum"><p>14</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">相対ホモロジー</p>
# <div class="pageNum"><p>15</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">多様体ホモロジー</p>
# <div class="pageNum"><p>16</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">ホモロジー多様体</p>
# <div class="pageNum"><p>16</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">向きづけ可能性</p>
# <div class="pageNum"><p>17</p></div>
#  </div>

# %% [markdown]
# <div class = "contents">
# <p class = "Chapter">コホモロジー</p>
#  <div class="pageNum"><p>20</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">コホモロジー群</p>
#  <div class="pageNum"><p>20</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">積 </p>
# <div class="pageNum"><p>25</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">ホイットニー類</p>
#  <div class="pageNum"><p>25</p></div>
# </div>

# %% [markdown]
# <div class = "contents">
# <p class = "Chapter">パーシステント・(コ)ホモロジー</p>
# <div class="pageNum"><p>28</p></div>
# </div>
# <div class = "contents">
# <p class ="Section">構造定理</p>
# <div class="pageNum"><p>28</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">パーシステントホモロジー</p>
# <div class="pageNum"><p>28</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">パーシステントコホモロジー</p>
# <div class="pageNum"><p>31</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">パーシステントホイットニー類</p>
# <div class="pageNum"><p>31</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">自然画像データのパーシステントホモロジー</p>
# <div class="pageNum"><p>32</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">$S^7$へのパッチの射影</p>
# <div class="pageNum"><p>33</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">パッチの高密度空間における結果</p>
# <div class="pageNum"><p>34</p></div>
# </div>

# %% [markdown]
# <div class = "contents">
# <p class = "Chapter">多様体上の点データに対するパーシステントホモロジー</p>
# <div class="pageNum"><p>36</p></div>
# </div>
#
# <div class = "contents">
# <p class = "Section">多様体上の距離</p>
# <div class="pageNum"><p>36</p></div>
# </div>
#
# <div class = "contents">
# <p class = "Subsection">円周$S^1$</p>
# <div class="pageNum"><p>36</p></div>
# </div>
#
# <div class = "contents">
# <p class = "Subsection">実射影直線$P^1$</p>
# <div class="pageNum"><p>37</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">$n$次元トーラス</p>
# <div class="pageNum"><p>38</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">クライン・ボトル</p>
# <div class="pageNum"><p>38</p></div>
# </div>
# <div class = "contents">
# <p class = "Section">いくつかの実験</p>
# <div class="pageNum"><p>40</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">一様乱数</p>
# <div class="pageNum"><p>40</p></div>
# </div>
# <div class = "contents">
# <p class = "Subsection">正規分布の場合</p>
# <div class="pageNum"><p>45</p></div>
# </div>

# %% [markdown]
# <div class = "contents">
# <p class = "Chapter">まとめ</p>
# <div class="pageNum"><p>47</p></div>
# </div>

# %% [markdown]
# <div class = "contents">
# <p class = "Chapter">参考文献</p>
# <div class="pageNum"><p>47</p></div>
# </div>
#
# <script>
#     var contentsList = Array.from(document.getElementsByClassName("contents"));
#     dottedline = (element) => {
#         const sectionName = element.firstElementChild;
#         const pageNumber = element.lastElementChild;
#         const dottedline = document.createElement('p');
#         dottedline.textContent = "\u00A0 .";
#         console.log("test");
#         element.insertBefore(dottedline, pageNumber);
#     }
#
#
#     for (const element of contentsList) {
#         dottedline(element);
#     }
# </script>

# %%
from IPython.display import HTML, display
script = """
<script type = "text/Javascript">
            var contentsList = Array.from(document.getElementsByClassName("contents"));
            const dotPix = 12;
            
            for (const element of contentsList) {
            const sectionName = element.firstElementChild;
            const pageNumber = element.lastElementChild;
            const dottedline = document.createElement('p');
            
            var maxDottedLength = element.clientWidth - sectionName.clientWidth - pageNumber.clientWidth;
            var i = 0;
            while (i * dotPix < maxDottedLength){
                dottedline.textContent += "\u00A0 .";
                i+=1;
            }
            
                element.insertBefore(dottedline, pageNumber);
            }
</script>
"""
display(HTML(script))
# Out:
# <script type = "text/Javascript">
#             var contentsList = Array.from(document.getElementsByClassName("contents"));
#             for (const element of contentsList) {
#             const sectionName = element.firstElementChild;
#             const pageNumber = element.lastElementChild;
#             const dottedline = document.createElement('p');
#             dottedline.textContent = "  .";
#             element.insertBefore(dottedline, pageNumber);
#             }
#
#             for (const element of contentsList) {
#             const sectionName = element.firstElementChild;
#             const pageNumber = element.lastElementChild;
#             const dottedline = pageNumber.previousElementSibling;
#             console.log(dottedline.clientWidth);
#             }
# </script>
