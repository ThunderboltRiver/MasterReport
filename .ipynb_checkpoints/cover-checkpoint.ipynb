# %% [markdown]
# <div class = "cover">
#     <div class = "Attribute">
#         <p>修士論文</p>
#      </div>
#     <div class = "Title">
#         <p >多様体上のデータクラウドと</p>
#         <p>パーシステントホモロジー</p>
#         <p>沖田 大河</p>
#     </div>
#     <div class = "Join">
#         <p>2023.2</p>
#         <p>北海道大学大学院情報科学院情報科学先行</p>
#         <p>情報理工学コース &emsp; 応用特異点論研究室</p>
#         <p>修士課程</p>
#     </div>
# </div>
