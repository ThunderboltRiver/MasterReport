# %% [markdown]
# # 序文

# %% [markdown]
# &emsp;本修士論文では,具体的な多様体上にある点データ群(データクラウド)に対するパーシステントホモロジーを定義し ,&thinsp; 人工データによる計算機実験を行なった。また,多様体の向きづけ可能性などに関わるコホモロジー特性類のパーシステントホモロジー版の導出と検証について考察した.
# &emsp;画像認識などのデータサイエンスの分野において最近傍法やニューラルネットなどさまざまな方法が提案されている. &thinsp;近年,位相的データ解析(Topological Data Analysis)を総称される位相幾何学的分析手法が注目されている.&thinsp;とくにパーシステントホモロジー群は,&thinsp;データの集合が全体的にどのような位相的特徴をもっているのかを表現するのに優れた道具である. &thinsp;実際にタンパク質の折りたたみ構造の分析や,&thinsp;重みがついたネットワークのトポロジーの分析,&thinsp; ガラスなどのアモルファス素材の構造解析,&thinsp; ゲノム解析などに使用されて成果を上げている.
# &emsp;さて,いわゆる多様体仮説とは,高次元ユークリッド空間上にスパースに分布する点データ群が低次元のある部分多様体の近傍に一様に分布しているたろうとするものである.この多様体仮説の具体的な一例として,Carlsson,Mumfordらによる自然背景画像の位相的データ分析が用いられている[1,2,3].&thinsp; 数百万個グレースケールの自然画像データから$3 \times 3$パッチをランダムに取ったところ,&thinsp;パッチのデータ空間上に点データ群がスパースに分布し,パーシステントホモロジーの計算を通じて,&thinsp;ある2次元部分多様体(閉曲面)の近くに高密度にデータが存在することが検証された.とくにこの多様体はクライン・ボトルに同相であって向きづけ不可能な曲面として知られている.
# &emsp; 本修士論文ではMumford らの研究を動機づけとして逆に多様体$M$とその上に分布する点データ群$D$が与えられたとき,&thinsp; $D$のパーシステントホモロジーをどのように定義するかという問から考察した.まずあらかじめ多様体$M$にその位相と一致する距離を導入して点データ群$D$の各$2$点間の距離を計算し,&thinsp; 隣接行列,すなわち重みつきグラフを生成する.&thinsp; このグラフは仮想的に高次元のユークリッド空間に埋め込まれるだろう.&thinsp; これはいわばナッシュの埋め込み定理で保証されるリーマン多様体$M$のユークリッド空間への埋め込みの仮想的実験ともみなせると思われる.&thinsp; このユークリッド空間内の点データ群のヴィートリス・リップス複体によるパーシステントホモロジー群を考える.&thinsp; これは多様体$M$のホモロジーを近似するものではないが,点データ群$D$が$M$上で一様に分布しているならば,ある時刻を固定すると$M$のホモロジーを復元すると考えられる.&thinsp; Mumfordらの研究に関連して,&thinsp; $M$を閉曲面,特にクライン・ボトルやトーラスを扱うことにして人工的に生成した点データ群として$M$上の増大するフィルトレーションが与えられたとき,$M$の接束で$M$のStifel-Whitney類のパーシステント版を定義した.&thinsp; 上述の計算機実験に現れるバーコードにおいて,&thinsp; パーシステントバーコードにおいて,&thinsp; パーシステントホイットニー類を同定した.&thinsp; 将来的には高次元のトーラスや球面上の方向統計学における実データを用いて,本修論で考察した手法を適用し,&thinsp; 検証したいと考える. &thinsp;
#
# <!-- さて,&thinsp;Carlsson, &thinsp;Ghrist, &thinsp; Mumfordたちはグレースケールの自然の背景画像から$3 \times 3$のパッチをランダムに複数取ったところ, &thinsp;そのデータ集合がある閉曲面のまわりに分布している傍証を,&thinsp; パーシステントホモロジーを用いて示した.&thinsp;この閉曲面はクライン・ボトルであって$0$次と$2$次のホモロジーが$1$であり, &thinsp;$1$次のホモロジーが$1$の$2$次元多様体ではあるが, &thinsp;特に向きづけ不可能な多様体であるという特徴がある. -->

# %% [markdown]
# <!-- &emsp;多様体の向きづけ可能性を判定するための特徴量として, &thinsp;ベクトル束に対するホイットニー類がある. &thinsp;データの集合$D$を含むユークリッド空間内の集合$B ( D \subset B \subset \mathbb{R}^N)$集合上にベクトル束の構造が入るなら, &thinsp;そこでホイットニー類を考えることができる. &thinsp;そこで本論文ではホイットニー類のパーシステント化に係る理論を構築し, &thinsp;それを用いたデータ集合の近似する多様体の向きづけ可能性の判定方法を述べる. &thinsp;またデータの集合が高次元であったとしても何らかの次元削減を用いて低次元のユークリッド空間の点に変換することを考えれば, &thinsp;多様体は元々低次元のものであると仮定してよいだろうし, &thinsp;高々向きづけ可能性とホモロジーについてのみ考えるのなら, &thinsp;近似する多様体の種類自体はそこまで多くはないと考えられる. &thinsp;そこで本研究では, &thinsp;近似する多様体を推論するというよりは, &thinsp;あらかじめいくつかの多様体を想定して, &thinsp;その多様体上に点データが存在すると仮定する立場をとる. &thinsp; そして想定する多様体の位相構造と一致する距離を定義してパーシステントホモロジーを計算した結果を述べる. &thinsp; -->

# %% [markdown]
# # &thinsp; ホモロジー
# &emsp;位相幾何学では, &thinsp;球体やトーラスなどのユークリッド空間内の図形から連結成分や輪っかや空洞の数と言った幾何学的な特徴を捉える際に, &thinsp;一度図形を簡単な多面体に近似(変形)して, &thinsp;代わりにこの多面体の特徴を捉えるといった手法を用いる. &thinsp;しかし雑に近似したところで, &thinsp;元の図形の関心のある特徴が大きく崩れては意味がない. &thinsp;そこで用いられる主な近似の手法として, &thinsp;位相同型やホモトピー同値が挙げられる. &thinsp;これら二つの変形によって, &thinsp;図形の見た目を大きく変えたとしても関心のある特徴を保存することができる. &thinsp;例えば, &thinsp;連結成分や輪っかや空洞の数について関心があれば元の図形とホモトピー同値な多面体を調べれば良い. &thinsp;それよりももっと多くのことを調べる際は, &thinsp;ホモトピー同値よりも近似度合いの強い位相同型な多面体について調べれば良い. &thinsp;このようにして考察の対象を多面体のみに狭めることができる. &thinsp;\
# そこでこのセクションでは多面体とは何かについて述べた後, &thinsp;連結成分や輪っかや空洞の数を調べる際の代数学的な概念であるホモロジー群について解説する. &thinsp;その後, &thinsp;本論文での考察対象となるホモロジー多様体について解説する. &thinsp;

# %% [markdown]
# ## &thinsp; 単体複体

# %% [markdown]
# ### &thinsp; 単体複体と多面体
# 多面体は, &thinsp; &thinsp;単体と呼ばれる簡単な図形がいくつか合併したものと捉え,&thinsp;その単体の集まりが単体複体として定義される. &thinsp;そこで先に単体と単体複体について解説する. &thinsp;

# %% [markdown]
# #### 定義
# $R^N$内の$n + 1$個の点$a_0, \cdots , a_n$に対して, &thinsp;ベクトル$\vec{a_0a_1}, \cdots, \vec{a_0a_n}$が一次独立である(一般の位置にある)とき, &thinsp;集合
# $$|a_0, \cdots, a_n| = \{\sum_{i = 0}^{n} \lambda_i a_i | \lambda_i \geq 0 (i = 0, \cdots, n) \sum_{i = 0}^{n}\lambda_i = 1\}$$
# を,$a_0, \cdots, a_n$を頂点とする **$n$次元単体** といい, &thinsp;$\sigma = |a_0, \cdots, a_n|$などと書く. &thinsp;\
# $\sigma$が単体であるとき, &thinsp;$\sigma$の頂点集合$\{a_0, \cdots, a_n\}$の空でない部分集合を頂点とする単体$\tau$を$\sigma$の**辺単体**といい, &thinsp;$\tau \preceq \sigma$と書く. &thinsp;単体$\sigma$が$n$次元であることを$\dim \sigma = n$と書く. &thinsp;

# %% [markdown]
# #### 定義
# $R^N$内のいくつかの単体からなる有限集合$K$であって, &thinsp;以下の条件を満たすものを **単体複体** という. &thinsp;
# $$(i) \sigma \in K, \tau \preceq \sigma \Longrightarrow \tau \in K$$
# $$(ii) \sigma, \tau \in K \sigma \cap \tau \ne \emptyset \Longrightarrow  \sigma \cap \tau \preceq \sigma, \tau$$
# ここで空集合$\emptyset$も単体複体であると定義する. &thinsp;$K \ne \emptyset$のときは$K$の$0$単体は **$K$の頂点** とよばれ, &thinsp;それら全体の集合を$\hat K$などと書く. &thinsp; $n:= \max{\{\dim \sigma | \sigma \in K \}}$を単体複体 $K$ の**次元**といい, &thinsp;$\dim K = n$と書く. &thinsp;また, &thinsp;単体複体$K$の全ての単体の和集合
# $$|K| :=  \bigcup_{\sigma \in K} \sigma$$
# を$K$の**多面体**という. &thinsp;$K = \emptyset$のときは$K$の次元は定義せず,&thinsp;多面体は$\emptyset$と定義する. &thinsp;

# %% [markdown]
# ホモロジー多様体や後のセクションで述べるパーシステント性において必要になる部分複体とその具体例について述べる. &thinsp;
#
# #### 定義
# 単体複体$K$の部分集合$L \subset K$がまた単体複体であるとき, &thinsp;$L$を$K$の **部分複体** という. &thinsp;\
# $L \subset K$が部分複体であるための必要十分条件は, &thinsp;定義1. &thinsp;1. &thinsp;2の条件$(i)$を満たすことである. &thinsp;

# %% [markdown]
# #### 例
# $K$を単体複体とし, &thinsp;$p \in |K|$を多面体の点とする. &thinsp;
# $$S_K(p) := \{\tau \in K | \exists \sigma \in K s.t \ \  p \in \sigma , \tau \prec \sigma \}$$
# $$L_K(p):= \{ \tau \in S_K(p)| p \notin \tau \}$$
# とおくと, &thinsp;これらはともに$K$の部分複体である. &thinsp;それぞれ **$K$における$p$の星状複体,&thinsp;まつわり複体** という.&thinsp;
# &emsp;直感的な言い方をすると, &thinsp;$p \in |K|$のまつわり複体とは, &thinsp;多面体$|K|$内で$p$に触れることなく囲うように位置する$K$の単体を全て集めた単体複体といえる. &thinsp;

# %% [markdown]
# ### &thinsp; 単体複体の組み合わせ構造
# &emsp;多面体を構成するには単体複体を構成する必要があるが, &thinsp;単体はユークリッド空間の図形であるからいちいちこれを作り上げるのは手間がかかる. &thinsp;また, &thinsp;多面体の辺の長さや面積, &thinsp;体積, &thinsp;内角といった量に元から関心がないなら, &thinsp;一般の位置にある点を具体的に考える必要はない. &thinsp;\
# &emsp;例えば多面体として三角形を何か一つ構成する際, &thinsp;どんな形だろうととにかく三角形でありさえすれば良い場合は具体的な頂点を取る必要がなく, &thinsp;あくまで$3$つの頂点が一般的な位置にあるという情報だけで事足りる. &thinsp;\
# &emsp;この視点で単体複体の頂点全体に注目すると, &thinsp;各単体はその頂点の組み合わせ(部分集合)として捉えられることがわかる. &thinsp;より具体的には次の命題1. &thinsp;1. &thinsp;5が成り立つ. &thinsp;

# %% [markdown]
# #### 命題
# $K$を単体複体とする. &thinsp;$K$の頂点全体の集合$\hat K$の部分集合族$\Sigma$を, &thinsp;$K$の単体の頂点集合全体として定義する. &thinsp;
# $$\Sigma := \{\{a_0, \cdots, a_k \} \subset \hat K | k \geq 0, |a_0, \cdots, a_k| \in K \} \cup \{ \emptyset \}$$
# このとき$\hat K$と$\Sigma$は次のような性質を持つ. &thinsp;
# $$(i) \forall v \in \hat K, \{v\} \in \Sigma $$
# $$(ii)\hat \sigma \in \Sigma, \hat \tau \subset \hat \sigma \Longrightarrow \hat \tau \in \Sigma $$
# $proof)$
# $(i):v \in \hat K$は$K$の頂点, &thinsp;つまり$0$単体であるから$|v| = v \in K$である. &thinsp;従って$\{ v \} \in \Sigma$\
# $(ii):\hat \sigma \in \Sigma$を頂点集合とする$K$の単体を$|\hat \sigma|$とする. &thinsp;$\hat \tau \subset \hat \sigma$が空でないなら, &thinsp;$|\hat \tau| \prec |\hat \sigma|$である. &thinsp;$K$が複体であることから, &thinsp;定義1. &thinsp;1. &thinsp;2の条件$(i)$より$|\hat \tau| \in K$よって$\hat \tau \in \Sigma$ . &thinsp;$\square$

# %% [markdown]
# &emsp;命題1. &thinsp;1. &thinsp;5は幾何学的な概念である単体複体から条件$(i), (ii)$にあるような組み合わせ論的な構造を抽出できることを示している. &thinsp;そこで次のように定義する. &thinsp;
# #### 定義
# 有限集合$V$とその部分集合族$\mathcal{S}$が以下の条件を満たすとき, &thinsp;対$(V, \mathcal{S})$を**抽象複体**と言う. &thinsp;
# $$(i) \forall v \in V, \{ v \} \in \mathcal{S}$$
# $$(ii) \hat \sigma \in \mathcal{S}, \hat \tau \subset \hat \sigma \Longrightarrow \hat \tau \in \mathcal{S} $$
# このとき$V$は **頂点集合** と呼ばれ, &thinsp;その元を **頂点** という. &thinsp;$\mathcal{S}$ の元$\hat \sigma$は, &thinsp;その元の個数が$n + 1$であるなら $n$**次元単体** と呼ばれ, &thinsp;$\dim \hat \sigma = n$と書く. &thinsp;

# %% [markdown]
# #### 例
# 距離空間$(X, d)$の有限個の点からなる集合$P = \{x_1, \cdots, x_n\}$と$r >0$に対して, &thinsp;抽象複体$VR_r(P) = (V, \mathcal{S})$を以下で定義する. &thinsp;
# $$ V := \{1, \cdots, n \} \\ \mathcal{S} := \{ B \subset V |  \forall i,j \in B, d(x_i, x_j) \leq 2r \}$$
# $VR_r(P)$を**ヴィートリスリップス複体**という. &thinsp;

# %% [markdown]
# &emsp;抽象複体という視点に立つと$n$単体は$n + 1$個の元からなる集合として捉えられ, &thinsp;それらの集合族によって単体複体の大まかな形が実現されていると捉えることができる. &thinsp;
# &emsp;次に二つの抽象複体の間に定義される写像であって, &thinsp;単体を単体へ対応させるものについて定義する. &thinsp;

# %% [markdown]
# #### 定義
# 二つの抽象複体$(V, \mathcal{S}), (V', \mathcal{S}' )$の頂点集合の間の写像$\phi: V \longrightarrow V' $は, &thinsp;以下の条件を満たすとき単体写像という. &thinsp;
# $$\hat \sigma \in \mathcal{S} \Longrightarrow \phi(\hat \sigma) \in \mathcal{S}'$$
# このとき$\phi: (V, \mathcal{S}) \longrightarrow (V', \mathcal{S}')$などと書く. &thinsp;また, &thinsp;二つの単体複体$K,L$に命題1. &thinsp;1. &thinsp;5を適用することで得られる抽象複体の間に単体写像を構成したときは単に$\phi:K \longrightarrow L$などと書く. &thinsp;\
# 単体写像は単射であるとは限らないから, &thinsp;写った先の単体の次元は, &thinsp;元の単体より少ない可能性がある. &thinsp;もし単射であるなら次元は保たれる. &thinsp;\
# この単体写像を用いて抽象複体の同型について定義する. &thinsp;これは幾何学的は, &thinsp;二つの単体複体に同じ組み合わせ的構造があることを示すものである. &thinsp;

# %% [markdown]
# #### 定義
# 単体写像$\phi: (V, \mathcal{S}) \longrightarrow (V', \mathcal{S}')$は, &thinsp;全単射であり, &thinsp;その逆写像もまた単体写像であるとき, &thinsp;**単体同型写像** という. &thinsp;
# さらにこのとき, &thinsp;二つの抽象複体$(V, \mathcal{S}),(V', \mathcal{S}')$は**同型**であるという. &thinsp;

# %% [markdown]
# 命題1. &thinsp;1. &thinsp;5は幾何学的な単体複体から抽象複体を構成したが, &thinsp;この逆もまた成り立つ. &thinsp;
# #### 命題
# 抽象複体$(V, \mathcal{S})$に対して, &thinsp;命題1. &thinsp;1. &thinsp;5の$(\hat K, \Sigma)$と同型になるような単体複体$K$を構成できる. &thinsp;
# この$K$を抽象複体$(V, \mathcal{S})$の**幾何学的実現**という. &thinsp;\
# $proof)V = \{v_0, \cdots, v_N \}$とするとき, &thinsp;$\mathbb{R}^N$の標準基底$\boldsymbol{e}_i (i = 1, \cdots, N)$を取る. &thinsp;$\boldsymbol{e}_0 = \boldsymbol{0}$とするとき,$\boldsymbol{e}_0, \cdots, \boldsymbol{e}_N$は一般の位置にある. &thinsp;そこで単体複体$K$を次で定義する. &thinsp;
# $$K := \{|\boldsymbol{e}_{i_0}, \cdots, \boldsymbol{e}_{i_k}| \ | \{v_{i_0}, \cdots, v_{i_k} \} \in \mathcal{S},  \{i_0, \cdots, i_k\} \subset \{0, \cdots, N\}, k \geq 0 \} \}$$
# この$K$に命題1. &thinsp;1. &thinsp;5を適用して得られた$(\hat K, \Sigma)$と抽象複体$(V, \mathcal{S})$との間に写像$\phi:V \longrightarrow \hat K$を$\phi(v_i) = \boldsymbol{e}_i$で定義するとこれが同型な単体写像となる. &thinsp;$\square$
#
# &emsp; 命題1. &thinsp;1. &thinsp;5と命題1. &thinsp;1. &thinsp;9により, &thinsp;単体複体を構成する際は抽象複体のみを考えるだけで十分であることがわかる. &thinsp;

# %% [markdown]
# ### &thinsp; 単体分割
# &emsp;以上で多面体の解説を終えるが,&thinsp; 最後に多面体を一般の図形に近似するための単体分割について述べる. &thinsp;

# %% [markdown]
# #### 定義
# 2つの位相空間$X, Y$が位相同型であるとは,&thinsp;2つの連続写像$f:X \longrightarrow Y, g:Y \longrightarrow X$が存在して
# $$g \circ f = id_{X} \ \ \ f \circ g = id_{Y}$$
# となることをいう. &thinsp;ここで$id_{X}$は位相空間$X$の恒等写像である. &thinsp;

# %% [markdown]
# #### 定義
# 位相空間$M$が, &thinsp;ある単体複体$K$の多面体と位相同型であるとき, &thinsp;同相写像$t:K \longrightarrow M$を**単体分割**といい,$M$は単体分割可能であるという. &thinsp;
# 単体分割によって一般の図形を単体複体に置き換えて考察することが可能になる. &thinsp;

# %% [markdown]
# ### &thinsp; 脈体定理

# %% [markdown]
# #### 定義
# 位相空間$X$がその部分集合族$\Phi = \{F_i | i = 1 , \cdots, m\}$によって被覆
# $$X = \bigcup_{i = 1}^m F_i$$
# されているとする, &thinsp;このとき以下で定義される抽象単体複体$(V, \mathcal{S})$を$\Phi$の**脈体**といい$\mathcal{N}(\Phi)$で表す. &thinsp;
# $$V:= \{1, \cdots, m\} \\ \mathcal{S} = \{ S \subset V | \bigcap_{i \in S} F_{i} \ne \emptyset\}$$

# %% [markdown]
# #### 例
# 距離空間$(X, d)$の有限個の点からなる集合を$P={x_1, \cdots, x_n}$とする. &thinsp;半径$r > 0$の閉球体の集まり$\Phi = \{B(x_i, r) | i = 1, \cdots, n\}$の脈体$\mathcal{N}(\Phi)$を半径$r$の**チェック複体**といい$C_r(P)$で表す. &thinsp;

# %% [markdown]
# #### 例
# 距離空間$(X, d)$の有限個の点からなる集合を$P = \{x_1, \cdots, x_n \}$する. &thinsp;各$x_i$のボロノイ領域$V(x_i) := \{ x \in X | d(x, x_i) \leq d(x, x_j)  \ \forall j \}$と半径$r$の閉球体$B(x_i, r)$の共通部分を$(x_i, r) := V(x_i) \cap B(x_i, r)$とするとき,$\Phi = \{W(x_i, r) | i = 1, \cdots, n\}$の脈体を半径$r$の**アルファ複体**といい,$\alpha_r(P)$で表す. &thinsp;

# %% [markdown]
# #### 定理
# (脈体定理)
# $X$を位相空間とし,$\Phi = \{F_i | i= 1, \cdots, m \}$をその開(閉)被覆
# $$X = \bigcup_{i =1}^m F_i$$
# とする. &thinsp;$\Phi$のいくつかの集合による空でない交差が一点に可縮であるならば$\Phi$の脈体$\mathcal{N}(\Phi)$の幾何学的実現は$X$にホモトピー同値である. &thinsp;つまり
# $$X \simeq | \mathcal{N}(\Phi)|$$
# が成り立つ. &thinsp;

# %% [markdown]
# ## &thinsp; ホモロジー群

# %% [markdown]
# ### &thinsp; 複体のホモロジー
# &emsp;多面体内に$n$次元の穴がいくつあるかと言ったことを代数学的に調べる手法としてホモロジー群がある. &thinsp;ここでは一旦,&thinsp;ホモロジー群の直感的な説明を簡単に行う. &thinsp;\
# &emsp;多面体に含まれる図形は, &thinsp;単体複体内のいくつかの単体の和集合として大雑把に表現できる. &thinsp;従って, &thinsp;多面体内の穴もまたいくつかの単体の和集合として解釈できる. &thinsp;しかし, &thinsp;穴の情報だけが欲しいのなら,&thinsp;ループのような形をした図形のみを考えればよく,&thinsp;さらに言えば,「中身(内部)が埋まっているなら無視する」という規則を設けた方が便利である. &thinsp;\
# &emsp;上記の考え方は代数学的に厳密に表現することが可能で,&thinsp;特に「中身(内部)が埋まっているなら無視する」という規則は商群によって表現することができる. &thinsp;この商群をホモロジー群という. &thinsp;\
# このセクションでは,&thinsp;これをもう少し厳密な言い方で表現する. &thinsp;そのためにまずは集合論的な和集合を,&thinsp;代数学的な形式和として捉え直すことから始める. &thinsp;これが鎖群の考え方である. &thinsp;

# %% [markdown]
# #### 定義
# $K$を空でない単体複体とする. &thinsp;$K$の$q$次元単体全体を基底とする,&thinsp;体$\mathbb{Z}_2$上のベクトル空間を$K$の**$q$次元鎖群**といい$C_q(K)$と書く. &thinsp;つまり,$\sigma_1^{q}, \cdots, \sigma_{k_q}^q$を$K$の$q$次元単体全体とするとき
# $$C_q(K) := \{\sum_{i = 1}^{k_q}m_i \sigma_i^{q}| m_i \in \mathbb{Z}_2 \ , i = 1, \cdots, k_q\}$$
# と定義する. &thinsp;$q > \dim K$と$q < 0$のときは$C_q(K) = \boldsymbol{0}$と定義する. &thinsp;また$K = \emptyset$のときは任意の$q$に対して$C_q(K) = \boldsymbol{0}$と定義する. &thinsp;ここで$c \in C_q(K)$を**$q$次元鎖**という. &thinsp;\
# &emsp;鎖群の構成によって,&thinsp;集合論的な単体の和集合は鎖として表現される. &thinsp;ただし,&thinsp;鎖として単体を表すときは$\sigma = \langle a_0, \cdots, a_q \rangle$などと書くことにする. &thinsp;

# %% [markdown]
# 次に「ループのような図形」や「中身が詰まっている」という表現をより詳細化するために境界準同型という鎖群間の写像を定義する. &thinsp;
# #### 定義
# 整数$q$を$1 \leq q \leq \dim K$とするとき,$K$の$q$次元単体$\sigma =  \langle a_0, \cdots, a_q \rangle \in C_q(K)$の境界$\partial_q (\sigma) \in C_{q - 1}(K)$を以下で定義する. &thinsp;
# $$\partial_q (\sigma) := \sum_{i = 0}^{q}\langle a_0, \cdots,a_{i - 1}, a_{i + 1}, \cdots a_q \rangle$$
# さらに一般の$q$次元鎖$c = \sum_{i = 1}^{k_q} m_{i} \sigma_i^q \in C_q(K)$に対しては
# $$\partial_q(c) := \sum_{i = 1}^{k_q}m_i \partial_q (\sigma_i^{q})$$
# と定義する. &thinsp;ただし,&thinsp;ここで$\sigma_i^{q} (i =1, \cdots, k_q )$は単体複体$K$の$q$次元単体全体とする. &thinsp;\
# $q > \dim K$あるいは$q \leq 0$となる$q$に対しては
# $$\partial_q(c) := \boldsymbol{0} \ \ c \in C_q(K)$$
# と定義する. &thinsp;
# これによって任意の$q \in \mathbb{Z}$に対して準同型写像
# $$\partial_q : C_q(K) \longrightarrow C_{q - 1}(K)$$
# が定義される. &thinsp;これを **$q$次元境界準同型写像** という. &thinsp;

# %% [markdown]
# 　以上の準備のもとで「ループのような図形」をより厳密に「どの点からも始点と終点が同じであるように一筆書きできる図形」として定義し,&thinsp;その性質を考察することにする. &thinsp;\
# 　議論を簡単にするために一旦具体的に円周$S^1$についてのみ考える. &thinsp;まず$S^1$上に異なる３点をとることで単体分割が得られるが,&thinsp;そのどの頂点もちょうど2つの辺の頂点となっていることがわかる. &thinsp;これは点の数をどれだけ増やしていっても観測される. &thinsp;一方で,&thinsp;別の$S^1$と何処かの一点で同一視してできた図形(8の字ような図形)はどうなるだろうか. &thinsp;この場合,&thinsp;同一視された１点と他の異なる2点を,2つの$S^1$上からそれぞれ取ることで単体分割が得られ,&thinsp;そのどの頂点も偶数本の辺の頂点となっていることがわかる. &thinsp;\
# 　以上の考察から,&thinsp;位相空間$M$の内のループのような図形は,&thinsp;単体分割$t:K \longrightarrow M$とその鎖群$C_q(K)$の表現を用いると,&thinsp;次の条件を満たす鎖$c \in C_1(K)$として一般化できる. &thinsp;
# $$\partial_1(c) = \boldsymbol{0}$$

# %% [markdown]
# そこで上記の性質を持つ鎖を**単体複体$K$の$1$次のサイクル**と呼ぶことにする. &thinsp;こうして「ループのような図形」は1次のサイクルとして厳密に表現できた. &thinsp;\
# 　しかし,&thinsp;一口に$1$次のサイクルといっても「中身が詰まっている」ものと「穴になっている」ものがある. &thinsp;たとえば円板$D^2$は$S^1$を含むから$1$次のサイクルを持っているが,&thinsp;同時に「中身が詰まっている」図形でもある. &thinsp;一方で$S^1$自身は「穴になっている」図形である. &thinsp;よって次にこれを区別する方法を考える. &thinsp;\
# 　簡単のため$D^2$に対して考察する. &thinsp;$D^2$の境界上に異なる点を３つ取ると,$D^2$はあたかも$2$単体を伸ばしてできた図形として見做せる. &thinsp;つまり$D^2$の単体分割として,$2$単体の辺単体全体が考えられる. &thinsp;この単体分割において$2$単体に境界準同型$\partial_2$を施すことで$D^2$の部分集合としての$S^1$を表す鎖が得られる. &thinsp;\
# 　以上の考察から,&thinsp;中身が詰まっている鎖$c \in C_1(K)$とは,
# $$\exists c' \in C_2(K) \ s.t. \ \partial_2(c') = c$$
# となるものであると解釈できる. &thinsp;このような鎖を**単体複体$K$の$1$次のバウンダリ**と呼ぶことにする. &thinsp;上記の例では,$D^2$の部分集合としての$S^1$を表す鎖が$1$次のバウンダリであるが,&thinsp;特に$1$次のサイクルでもある. &thinsp;これは偶然のように思われるかもしれないが,&thinsp;一般に成り立つことである. &thinsp;このことを次の命題に示す. &thinsp;

# %% [markdown]
# #### 命題
# 境界準同型$\partial_q:C_q(K) \longrightarrow C_{q - 1}(K)$と任意の$q$に対して
# $$\partial_{q} \circ \partial_{q + 1} = \boldsymbol{0}$$
# が成り立つ. &thinsp;\
# $proof)q > \dim K$と$q \leq 0$のときは明らかだから$0 \leq q \leq \dim K$のときを示す. &thinsp;$\sigma = \langle a_0, \cdots, a_{q+1} \rangle$を$K$の単体とする. &thinsp;準同型性から$\partial_{q} (\partial_{q + 1} (\sigma)) = \boldsymbol{0}$を示せば良い. &thinsp;
# $$\partial_q(\partial_{q +1}(\sigma)) = \partial_q(\sum_{i = 0}^{q + 1}\langle a_0, \cdots, \hat a_{i}, \cdots, a_{q + 1} \rangle) \\ = \sum_{i = 0}^{q + 1}\sum_{j< i}\langle a_0, \cdots, \hat a_{j}, \cdots, \hat a_{i}, \cdots, a_{q + 1} \rangle + \sum_{i = 0}^{q +1} \sum_{i< j}\langle a_0, \cdots, \hat a_{i}, \cdots, \hat a_{j}, \cdots, a_{q + 1} \rangle$$
# ここで$\hat a_{i}$記号はその頂点を取り除くことを意味するものとする. &thinsp;$k < l$とすると上記の第一項において$i = l, j = l$としたものと第二項において$i = k, j = l$としたものは等しい. &thinsp;$k < l$は任意だったから
# $$\sum_{i = 0}^{q + 1}\sum_{j< i}\langle a_0, \cdots, \hat a_{j}, \cdots, \hat a_{i}, \cdots, a_{q + 1} \rangle + \sum_{i = 0}^{q +1} \sum_{i< j}\langle a_0, \cdots, \hat a_{i}, \cdots, \hat a_{j}, \cdots, a_{q + 1} \rangle = \boldsymbol{0}$$
# である. &thinsp;従って$\partial_{q} (\partial_{q + 1} (\sigma)) = \boldsymbol{0}$となる. &thinsp;$\square$

# %% [markdown]
# &emsp;命題1. &thinsp;2. &thinsp;3は集合の言葉で言い換えると
# $$Im \partial_{q +1} \subset \ker \partial_q$$
# を意味している. &thinsp;今までは$1$次のサイクルとバウンダリについてのみ考えていたが,&thinsp;上記の結果から一般の次元にも適用することが可能になる. &thinsp;
#
# #### 定義
# $z \in \ker \partial_q$を$q$**次元サイクル**といい,$b \in Im \partial_{q + 1}$を$q$**次元バウンダリ**という. &thinsp;
#
# &emsp;以上のことから,「中身が詰まった図形」は$q$次元バウンダリとして厳密に表現できる. &thinsp;従って「穴になっているループのような図形」はサイクルの内バウンダリでないものとして表現できる. &thinsp;集合としては純粋に$\ker \partial_q - Im \partial_{q + 1}$としたいところだが,&thinsp;この集合は単体分割$K$の取り方に大きく変動してしまう. &thinsp;\
# &emsp;そこで単体分割の取り方に依存せずに決まるものとして表現することを考える. &thinsp;まず,１つのサイクルにバウンダリを足してもまたサイクルであることは明らかである. &thinsp;従ってこのバウンダリの違いを無視した集合を考えたい. &thinsp;$Im \partial_{q +1} \subset \ker \partial_q$であったことと,&thinsp;この2つの集合はベクトル空間$C_q(K)$の部分ベクトル空間であることから商ベクトル空間の考えを適用できる. &thinsp;つまり次のように定義する. &thinsp;

# %% [markdown]
# #### 定義
# $\ker \partial_q$上に同値関係$\sim$を定義する. &thinsp;
# $$z \sim z' (z, z' \in \ker \partial_q) \overset{\text{def}}{\Longleftrightarrow} z - z' \in Im \partial_{q + 1}$$
# この同値関係による商集合を$H_q(K)$と書く. &thinsp;$[z]$で$z \in \ker \partial_q$の同値類を表し,$z$の**ホモロジー類**,&thinsp;あるいは単に**$q$次元ホモロジー類**という. &thinsp;$H_q(K)$上には$\ker \partial_q$から次のような和とスカラー倍が矛盾なく定義される. &thinsp;
# $$c[z] +c' [z'] := [cz + c'z'], \ \ \  c,c' \in \mathbb{Z}_2, z,z' \in \ker \partial_q$$
# これにより$H_q(K)$は体$\mathbb{Z}_2$上のベクトル空間になる. &thinsp;この$H_q(K)$を**$q$次元ホモロジー群**という. &thinsp;

# %% [markdown]
# #### 注意
# &emsp;一般にベクトル空間$V$とその部分空間$W$に対して,&thinsp;以下のような同値関係$\sim$
# $$v \sim v' (v, v' \in V) \overset{\text{def}}{\Longleftrightarrow} v - v' \in W$$
# を与えて得られる商集合は再びベクトル空間となり,&thinsp;これを商ベクトル空間と言って一般に$V/W$と書く. &thinsp;これに倣いホモロジー群も
# $$H_q(K) = \ker \partial_q/Im \partial_{q + 1}$$
# と表す. &thinsp;以降では$V/W$と書いたらそれは商ベクトル空間を表すものとする. &thinsp;

# %% [markdown]
# ### &thinsp; ホモトピー同値
#
# #### 定義
# 2つの位相空間$X,Y$の間の連続写像の族$\{f_t\}_{t \in [0, 1]}:X \longrightarrow Y$を考える. &thinsp;このとき,&thinsp;写像
# $$H(s, t) = f_t(s)$$
# が連続であるとき,&thinsp;これを$f_0$と$f_1$の間のホモトピーという. &thinsp;またこのとき$f_0$と$f_1$はホモトピックであるといい$f_0 \simeq f_1$と書く. &thinsp;
#
# #### 定義
# 2つの位相空間$X,Y$の間に2つの連続写像$f: X \longrightarrow Y, g:Y \longrightarrow X$が存在して
# $$g \circ f \simeq id_{X} \ \ \ f \circ g \simeq id_{Y}$$
# となるとき,$X$と$Y$はホモトピー同値であるという. &thinsp;
#
# &emsp;ホモロジー類は,&thinsp;直感には中身の詰まったサイクルを消して得られたものであるため,&thinsp;事実上同値関係$\sim$はホモトピー同値を代数的に表現したものといえる. &thinsp;つまり次の定理が成り立つ. &thinsp;
# #### 定理
# 単体複体$K,L$に対し,&thinsp;多面体$|K|$と$|L|$がホモトピー同値なら$H_q(K) \simeq H_q(L)$
#
# 　この定理によってホモロジー群が単体分割の違いに依らずに定まることがわかる. &thinsp;

# %% [markdown]
# ### &thinsp; 誘導準同型
#
# &emsp; 次にパーシステントホモロジーの構成に必要な二つのホモロジー群の間の準同型性について述べる. &thinsp;二つの単体複体の間に単体写像がある場合,&thinsp;そこから自然にホモロジー群の間に準同型な対応を与える. &thinsp;これが誘導準同型写像と呼ばれる. &thinsp;

# %% [markdown]
# &emsp;誘導準同型写像を定義するにあたって鎖群の間の準同型写像である鎖準同型について定義する. &thinsp;
# #### 定義
# $K,L$を単体複体とし,$\partial_q:C_q(K) \longrightarrow C_{q - 1}(K), \partial '_q : C_q(L) \longrightarrow C_{q - 1}(L)$をそれぞれの境界準同型とする. &thinsp;写像の族$\{ \varphi_q : C_q(K) \longrightarrow C_q(L)\}$が
# $$\forall q \in \mathbb{Z}, \varphi_{q - 1} \circ \partial_{q} =  \partial'_q \circ \varphi_q $$
# を満たすとき,$\{ \varphi_q \}$を**鎖準同型写像**という. &thinsp;

# %% [markdown]
# #### 例
# $\phi : K \longrightarrow L$を単体写像とする. &thinsp;$K$の$q$次元単体$\langle a_0, \cdots, a_{q+1} \rangle \in C_q(K)$に対して,&thinsp;準同型$\phi_q: C_q(K) \longrightarrow C_q(L)$を
# $$\phi_q(\langle a_0, \cdots, a_{q+1} \rangle) := \begin{cases} \langle \phi(a_0), \cdots , \phi(a_q) \rangle && \text{if} \dim \phi ( \{ a_0, \cdots, a_q \}) =q \\ \boldsymbol{0} && \rm{else} \end{cases}$$
# と定義すると$\{\phi_q\}$は鎖準同型写像となる. &thinsp;

# %% [markdown]
# &emsp;誘導準同型は鎖準同型を用いて次のような手順で定義される. &thinsp;
#
# &emsp;まず$\varphi_q: C_q(K) \longrightarrow C_q(L)$を鎖準同型とする. &thinsp;$z \in Ker \ \partial_q$とするとき,$\partial_q'(\varphi_q(z)) = \varphi_{q - 1}(\partial_q(z)) = \varphi_{q - 1}(\boldsymbol{0}) = \boldsymbol{0}$となるから
# $$z \in Ker \ \partial_q  \Longrightarrow \varphi_q(z) \in Ker \ \partial_q' $$
# が任意の$q \in \mathbb{Z}$で成り立つ. &thinsp;\
# &emsp;また$z,z' \in Ker \ \partial_q $のホモロジー類が同じ,&thinsp;つまり$z - z' \in Im \ \partial_{q + 1}$であるとする. &thinsp;この時$\varphi_q (z) - \varphi_q(z') \in \varphi_q(Im \ \partial_{q + 1})$となるが $\varphi_q(Im \ \partial_{q + 1}) = Im \ \varphi_q \circ \partial_{q + 1}  = Im \ \partial_{q + 1}' \circ \varphi_{q + 1}  = \partial_{q + 1}'(Im \ \varphi_{q + 1}) \subset Im \ \partial_{q + 1}'$ であるから
# $$z - z' \in Im \ \partial_q \Longrightarrow \varphi_q(z) - \varphi_q(z') \in Im \ \partial_{q + 1}'$$
# が任意の$q \in \mathbb{Z}$で成り立つ. &thinsp;\
# &emsp;以上の結果から,&thinsp;ホモロジー群の間の準同型$\varphi_{q*}:H_q(K) \longrightarrow H_q(L)$が
# $$\varphi_{q*} ([z]) = [\varphi_q(z)]$$
# によって矛盾なく定義される. &thinsp;これを鎖準同型${\varphi_q}$による**誘導準同型写像**という. &thinsp;これを下の定義にまとめる. &thinsp;
# #### 定義
# ホモロジー群の間の準同型写像$\varphi_{q*}:H_q(K) \longrightarrow H_q(L)$を鎖準同型${\varphi_q}$による**誘導準同型写像**という. &thinsp;

# %% [markdown]
# ### &thinsp; 相対ホモロジー
# &emsp; 今までは単体複体のホモロジーについて一通り述べたが,&thinsp;一般に単体複体の中には部分複体の構造が複数ある. &thinsp;ある部分複体を無視したときに得られる単体複体のホモロジーについて記述したものが相対ホモロジー群である. &thinsp; 相対ホモロジー群は主に後の章において使用するためここでは定義のみを述べるにとどめておくことにする. &thinsp;
#
# #### 定義
#
# $K$を複体として$L \subset K$を部分複体とする. &thinsp;このとき鎖群$C_q(K),C_q(L)$は$C_q(L) \subset C_q(K)$を満たす. &thinsp;そこで$q$**次元相対鎖群**$C_q(K, L)$を
# $$C_q(K, L) := C_q(K) / C_q(L)$$
# とおく. &thinsp;さらにこの定義において$L = \emptyset$の場合も許することにし,&thinsp;その際の相対鎖群は通常の鎖群$C_q(K)$を表すものとする. &thinsp;
# $\partial_q: C_q(K) \longrightarrow C_{q - 1}(K)$を境界準同型とすると$\partial_q(C_q(L)) \subset C_{q - 1}(L)$であるから
# $$c - c' \in C_q(L) (c , c' \in C_q(K)) \Longrightarrow \partial_q(c) - \partial(c') \in C_{q - 1}(L)$$
# が成り立つ. &thinsp;従って相対鎖群の間の境界準同型$\partial_q^*:C_q(K, L) \longrightarrow C_{q - 1}(K, L)$が
# $$\partial_q^*([c]) := [\partial_q(c)]$$
# として矛盾なく定義される. &thinsp;\
# $\partial_{q + 1} \circ \partial_q = \boldsymbol{0}$より$\partial_{q + 1}^* \circ \partial_q^*= \boldsymbol{0}$であるから,鎖群のときと同様に
# $$Im \partial_{q + 1}^*\subset  \ker  \partial_q^* $$
# が成り立つ. &thinsp;
# $$H_q(K, L) : = \ker  \partial_q^*/Im \partial_{q + 1}^*$$
# としたものを **$q$次元相対ホモロジー群** という. &thinsp;

# %% [markdown]
# ## &thinsp; 多様体のホモロジー

# %% [markdown]
# ### &thinsp; ホモロジー多様体

# %% [markdown]
# #### 定義
# 位相空間$M$が単体分割可能であり,&thinsp;その単体分割を$t:K \longrightarrow M$とし,$p \in M$とする. &thinsp;
# $$H_q(L_M(p)) := H_q(L_K(t^{-1}(p)))$$
# とおくとき,&thinsp;これを$M$の点$p$における**局所ホモロジー群**という. &thinsp;\
# さらに,&thinsp;ある自然数$n$が存在して,&thinsp;任意の点$p \in M$に対して
# $$H_q(L_M(p)) \simeq H_q(S^{n -1}) \ (q = 0, 1, \cdots)$$
# が常に成り立つとき,$M$を **$n$次元ホモロジー多様体** という. &thinsp;

# %% [markdown]
# #### 例
# 円周$S^1$はホモロジー多様体である. &thinsp;

# %% [markdown]
# #### 定理
# $n$次元ホモロジー多様体$M$の単体分割を$t:K \longrightarrow M$とすると,&thinsp;一般に次の性質が成り立つことが知られている. &thinsp;
# $$(i) \dim K = n$$
# $$(ii) \forall \sigma \in K \exists \tau \in K s.t. \sigma \prec \tau , \dim \tau = n$$
# $$(iii) \sigma \in K \dim \sigma = n - 1 \Longrightarrow \# \{\tau \in K | \sigma \prec \tau, \dim \tau = n \} = 2$$

# %% [markdown]
# ### &thinsp; 向きづけ可能性

# %% [markdown]
# &emsp;鎖群やホモロジー群の係数としては$\mathbb{Z}_2$を考えたが,$\mathbb{Z}$に置き換えても同様な方法でホモロジー群を構成できる. &thinsp;係数の集合を変更することによって多様体の向きづけ可能性を判定できるようになる. &thinsp;

# %% [markdown]
# #### 定義
# 有限集合$\{1, \cdots, q\}$からそれ自身への全単射$s:\{1, \cdots, q\} \longrightarrow \{1, \cdots, q\}$のことを$q$次の置換という. &thinsp;$q$次の置換全体を$S_q$で表すことにする. &thinsp;

# %% [markdown]
# #### 定義
# $q (\geq 2)$次の置換は偶置換か奇置換かに分類できることを思い出す. &thinsp;つまり,$q$次の偶置換全体の集合を$A_q$とし,&thinsp;奇置換の方を$B_q$とするとき,$q$次の置換全体は
# $$S_q = A_q \bigsqcup B_q$$
# とできる. &thinsp;このとき集合$\{A_q, B_q\}$の要素を **$q$次の向き**,&thinsp;あるいは単に**向き**という. &thinsp;また向き$s$とは異なる向きを$s$の**逆向き**といい,$-s$で表す. &thinsp;$1$次の置換は一つしかないから,&thinsp;向きはただ一つとしかない. &thinsp;

# %% [markdown]
# #### 定義
# $q$次元単体$\sigma$と,$q+1$次の向き$s$に対して,&thinsp;対$\sigma_s = (\sigma, s)$を$s$**によって向きのついた$q$次元単体**,&thinsp;あるいは単に**向きのついた単体**という. &thinsp;$\sigma$が逆向き$-s$を持つ場合は$\sigma_{-s} = - \sigma_{s}$と表すことにする. &thinsp;
# <!-- #### 定義
# $q$個の元からなる集合$X$上の置換$p$と一点集合$\{\boldsymbol{\cdot}\}$上の一つしかない置換$1_{{\{\boldsymbol{\cdot}}\}}$(恒等写像)に対して直和$X \sqcup \{\boldsymbol{\cdot}\}$上の置換$1_{\{\boldsymbol{\cdot}\}} * p$を,$p$の拡張として定義する. &thinsp;このとき$sgn(1_{{\{\boldsymbol{\cdot}}\}}*p)=sgn(p)$であるから,向き$s$の各置換$p$に対する$1_{\{\boldsymbol{\cdot}\}}*p$全体を考えると,それは$X \sqcup \{\boldsymbol{\cdot}\}$上のある一つの向き$s'$に含まれる. &thinsp;この向き$s'$を$1_{\{\boldsymbol{\cdot}\}}*s$と書くとき,向きのついた$q-1$次元単体$|a_1,\cdots, a_q|_{s}$と,その一般の位置にある点$a_0$との結びを,向きのついた$q$次元単体として
# $$|a_0|_{1_{\{\boldsymbol{\cdot}\}}} * |a_1, \cdots, a_q|_{s} = |a_0, \cdots, a_q|_{1_{\{\boldsymbol{\cdot}\}} *s}$$
# で定義する. &thinsp; -->
# <!-- &emsp;$\sigma$の頂点を$a_0, \cdots, a_q$と番号をつけて$\sigma = |a_0, \cdots, a_q|$と表すとき,向きのついた単体を$\sigma_s$を$sgn(s)\langle a_0, \cdots, a_q \rangle$で表す. &thinsp;ここで$sgn(s)$は$s$が偶置換の集合なら$1$,奇置換の集合なら$-1$になる数である. &thinsp; -->
# <!-- &emsp;$\sigma = |a_0, \cdots, a_q|$で,置換$t$が向き$s$に属する置換なら向きのついた単体を,置換$t$によって頂点を並び替えたもの,つまり
# $$\sigma_s = [a_{t(0)}, \cdots, a_{t(q)}]$$
# と表すことにする. &thinsp;ただし,$t(a_k) = a_{k'}$となる$k'$を$t(k)$としている. &thinsp;
# $t'$を$q + 1$次の置換とすると,$t' \circ t$もまた$q + 1$次の置換になるから,向きのついた単体
# $$[a_{t' \circ t(0)}, \cdots, a_{t' \circ t(q)}]$$
# を考えることができる. &thinsp;置換$t$の符号を$sgn(t)$とするとき,よく知られているように,$sgn(t' \circ t) = sgn(t')sgn(t)$が成り立つから$t'$が偶置換なら,$t' \circ t$と$t$の向きは同じで
# $$[a_{t' \circ t(0)}, \cdots, a_{t' \circ t(q)}] =  [a_{t(0)}, \cdots, a_{t(q)}]$$
# となるが,$t'$が奇置換なら
# $$[a_{t' \circ t(0)}, \cdots, a_{t' \circ t(q)}] \ne  [a_{t(0)}, \cdots, a_{t(q)}]$$
# である. &thinsp;そこで向きのついた単体$\sigma_s$に対して,その逆向きをもつ単体$\sigma_{-s}$を
# $$\sigma_{-s} = - \sigma_s$$
# で表すことにする. &thinsp;この意味で,任意の$q + 1$次の置換$t$に対して
# $$[a_{t(0)}, \cdots, a_{t(q)}] = sgn(t)[a_0,\cdots, a_q]$$
# が成り立つ. &thinsp;従って例えば$0 \leq i \leq q$とすれば,上記の式によって
# $$[a_i, a_0, a_1, \cdots, a_{i - 1}, a_{i + 1}, \cdots, a_{q}] = (-1)^i[a_0, \cdots, a_q]$$
# が成り立つ. &thinsp;当たり前だが,同じ向きに属する置換$t$の符号は変わらないから,向き$s$に属する置換の符号を$sgn(s)$で表す. &thinsp; -->

# %% [markdown]
# #### 定義
# 向きのついた$q$単体$\sigma_s = |a_0, \cdots, a_q|_{s}$と各$i$対し,$q$次の向き$s_i$を
# $$sgn(s_i) := (-1)^isgn(s)$$
# となるものとして定義する. &thinsp;ただしここで$sgn(s)$は$s$が偶置換の集合のときに$1$,&thinsp;奇置換の集合のときに$-1$となる数とする. &thinsp;この$s_i$を$\sigma$の$q-1$辺単体$\sigma_i = |a_0, \cdots,\hat a_i \cdots, a_q|$($\hat a_i$は$a_i$を取り除くの意味)に$s$から**導かれる向き**という. &thinsp;$s$から導かれる向きのついた$q - 1$辺単体$(\sigma_{i}, s_i)$を,$\hat \sigma_{s_i}$で表す

# %% [markdown]
# #### 定義
# 二つの$q$単体$\sigma, \tau$の共通部分$\gamma = \sigma \cap \tau $が$\sigma$と$\tau$とに共通の$q-1$辺単体であり,$\sigma$と$\tau$にそれぞれ向き$\langle \sigma \rangle$と$ \langle \tau \rangle$を決めたとする. &thinsp;\
# $\langle \sigma \rangle $から導かれる$\gamma$の向きと,$ \langle \tau \rangle$から導かれる$\gamma$の向きが逆になっているとき,&thinsp;二つの向き$\langle \sigma \rangle$と$ \langle \tau \rangle$は**同調**しているという. &thinsp;

# %% [markdown]
# #### 定義
# $n$次元ホモロジー多様体$M$の単体分割を$t:K \longrightarrow M$とすると,&thinsp;上述の定理1. &thinsp;1. &thinsp;2の性質$(iii)$から$K$の$n-1$単体はちょうど二つの$n$単体の辺単体となっている. &thinsp;$K$の全ての$n$単体に向きを定め,&thinsp;共通の$n-1$単体を持つ任意の二つの$n$単体の向きが同調しているようにできるとき,$n$次元ホモロジー多様体$M$は**向きづけ可能**であるという. &thinsp;

# %% [markdown]
# #### 定義
# 単体複体$K$の各$q$単体$\sigma_{i} \ i = 1, \cdots, m_q$に向きをそれぞれ定め,&thinsp;向きのついた単体$[\sigma_i] i = 1, \cdots, m_q$を作り,&thinsp;これらを基底とする自由$\mathbb{Z}$加群を$C_q(K, \mathbb{Z})$と書いて,$\mathbb{Z}$係数の$K$の$q$次元鎖群という. &thinsp;
# &emsp;$[\sigma_i]$の逆向き$-[\sigma_i]$と$C_q(K, \mathbb{Z})$元$(-1)[\sigma_i]$を同一視することで$C_q(K, \mathbb{Z})$は向きの取り方によらずに決まる. &thinsp;またこの同一視によって$sgn(s)=1$のときの$\sigma_s$をそのまま$\sigma$で書くと,$C_q(K, \mathbb{Z})$上では$\sigma_s = sgn(s)\sigma$が成り立つ. &thinsp;

# %% [markdown]
# #### 定義
# $q$次元境界準同型$\partial_q:C_{q}(K,\mathbb{Z}) \longrightarrow C_{q}(K, \mathbb{Z})$を,$\sigma_s = |a_0, \cdots, a_q|_s$に対して
# $$\partial_q(\sigma_s) = \sum_{i = 0}^{q}\hat \sigma_{s_i} = \sum_{i = 0}^{q}(-1)^i sgn(s) \sigma_i$$
# で定義する. &thinsp;ここで$\hat \sigma_{s_i}$は$s$から$\sigma_i = |a_0, \cdots,\hat a_i \cdots, a_q|$に導かれる向き$s_i$を入れた$q -1$辺単体$(\sigma_i, s_i)$のことである. &thinsp;なお$\partial_0 = \boldsymbol{0}$と定義する. &thinsp;

# %% [markdown]
# #### 定理
# 上記の境界準同型に対して
# $\partial_{q - 1} \circ \partial_{q} = \boldsymbol{0}$が成り立つ. &thinsp;

# %% [markdown]
# $proof)sgn(s) = 1$のときのみを考えればよい. &thinsp;
# $$\partial_{q -1 } \circ \partial_q(\sigma) = \partial_{q - 1}(\sum_{i = 0}^{q}(-1)^i \sigma_i) =  \sum_{i = 0}^{q}(\sum_{j < i}(-1)^{i + j}(\sigma_i)_j + \sum_{ i < j}(-1)^{i + j - 1}(\sigma_i)_j)$$
# ここで$k < l$とするとき,$i = k, j = l$のとき第二項と,$i = l, j = k$としたときの第一項が打ち消し合うから
# $$ \sum_{i = 0}^{q}(\sum_{j < i}(-1)^{i + j}(\sigma_i)_j + \sum_{ i < j}(-1)^{i + j - 1}(\sigma_i)_j) = \boldsymbol{0}$$
# が成り立つ. &thinsp;$\square$

# %% [markdown]
# &emsp;$\mathbb{Z}_2$係数のときと同様にサイクルとバウダリ,&thinsp;そしてホモロジー群を定義する. &thinsp;

# %% [markdown]
# #### 定義
# $\text{Ker} \partial_q$の元を$q$次元サイクル,$\text{Im}\partial_{q + 1}$の元を$q$次元バウンダリという. &thinsp;$\text{Ker} \partial_q$も$\text{Im}\partial_{q + 1}$も$C_q(K, \mathbb{Z})$の部分加群であり,&thinsp;上記の定理より
# $$\text{Im}\partial_{q + 1} \subset \text{Ker}\partial_q$$
# が成り立つから,$\text{Ker} \partial_q$の同値関係$\sim$を
# $$z \sim z' (z, z' \in \text{Ker} \partial_q) \Longleftrightarrow z - z' \in \text{Im}\partial_{q + 1}$$
# によって定義できる. &thinsp;この商集合を$H_q(K, \mathbb{Z})$と書く. &thinsp;

# %% [markdown]
# #### 命題
# $H_q(K, \mathbb{Z})$に次のような加法と整数倍が矛盾なく定義される. &thinsp;
# $$[z] + [z'] := [z + z'] \\ n[z] := [nz]$$
# この加法と整数倍により,$H_q(K,\mathbb{Z})$は$\mathbb{Z}$加群となる. &thinsp;$H_q(K,\mathbb{Z})$を$\mathbb{Z}$係数の$q$次元ホモロジー群という

# %% [markdown]
# &emsp;$\mathbb{Z}$係数のサイクルはどのような図形なのかについて考察する. &thinsp;定義式
# $$\partial_q(\sigma_s) = \sum_{i = 0}^{q}(-1)^i sgn(\langle \sigma \rangle) \sigma_i$$
# に注目する. &thinsp;各$\sigma_i$は当然$C_q(K, \mathbb{Z})$の基底になっている. &thinsp;従って,$\sigma_i$を辺単体とする他の$q$単体$\sigma'$が存在するなら$\partial_q(n \sigma + m \sigma') = 0 (n, m > 0)$となるためには,$\sigma_i$の係数が$0$すなわち$n(-1)^i sgn(\langle \sigma \rangle) + m(-1)^{i'}sgn(\langle \sigma' \rangle) = 0$でなければならない. &thinsp;この式は$|n| = |m|$となるが,$n, m >0$よりこれは$n = m$を意味する. &thinsp;よって
# $$(-1)^i sgn(\langle \sigma \rangle) = - (-1)^{i'}sgn(\langle \sigma' \rangle)$$
# を得る. &thinsp;この式は$\sigma$から$\sigma_i$に導かれる向きと,$\sigma'$から$\sigma_i$に導かれる向きが逆になっていることを意味する. &thinsp;つまり,$\langle \sigma \rangle$と$\langle \sigma' \rangle$は同調している. &thinsp;よって$K$が$n$次元ホモロジー多様体$M$に単体分割を与える複体であるとき,$n$次元サイクル(従って$n$次元ホモロジーの生成元)が一つ存在することと$M$の向きづけ可能性は一致することがわかる. &thinsp;実際に次の定理が成り立つ. &thinsp;
# <!-- $c = \sum_{\sigma} n_{\sigma} (\sigma, \langle \sigma \rangle) \in C_q(K, \mathbb{Z})$とする. &thinsp;$\partial_q(c) \in C_q(K, \mathbb{Z})$であるから$K$の$q - 1$辺単体全体を$\tau_j (j = 1, \cdots, m_{q - 1})$とするとき,$\partial_q(c) = \sum_{j}m_j (\tau_j, \langle \tau_j \rangle)$と書くことができる. &thinsp;$\partial_q$の定義に則れば$\tau_j$を辺単体とする$q$次元単体全体を$\sigma_{j_1}, \cdots, \sigma_{j_{k_j}}$とし,それぞれ$j_l$番目の頂点を除いたものが$\tau_j$と一致するものとするとき,鎖群は自由であるから
# $$m_j = \sum_{l = 1}^{k_j}n_{\sigma_{j_l}}(-1)^{j_l}sgn(\sigma_{j_l})$$
# 従って$\partial_q(c) = \boldsymbol{0}$なら任意の$j$に対して$m_j = 0$である必要がある. &thinsp;このとき$\sum_j m_j = 0$であるが,$\sigma_{j_l}$は$\tau_j$以外に$q$個の$\tau_k$を含むから
# $$0 = \sum_{i}m_j = \sum_{\sigma}n_\sigma(\sum_{k = 0}^{q}(-1)^k)sgn(\sigma) = (\frac{(-1)^q + 1}{2})(\sum_{\sigma}n_\sigma sgn(\sigma ))$$
# $\mathbb{Z}$は整域だから$q$が偶数のときは -->

# %% [markdown]
# #### 定理
# 弧状連結な$n$次元ホモロジー多様体$M$において次が成り立つ. &thinsp;\
# $(i)H_n(M, \mathbb{Z}) = 0 \ or \  \mathbb{Z}$\
# $(ii)M$が向きづけ可能である$\Longleftrightarrow H_n(M,\mathbb{Z})\simeq \mathbb{Z}$
#
# 弧状連結で向づけ可能な$n$次元ホモロジー多様体$M$に対して,$H_n(M,\mathbb{Z})$の生成元を一つ定めることを$M$に**向きをつける**と言い,&thinsp;この生成元を$M$の**基本ホモロジー類**と言う. &thinsp;
# &emsp;ちなみに$\mathbb{Z}_2$係数のホモロジー群$H_n(M)$では向きづけ可能性を判別することは不可能で,&thinsp;常に$H_n(M) \simeq \mathbb{Z}_2$である. &thinsp;それは$\mathbb{Z}_2$係数では$-1 = 1$が成り立つため,&thinsp;向きをどのように入れても自明に同調するからである. &thinsp;

# %% [markdown]
# #### 例
# $n- 1$次元球面$S^{n - 1}$は向きづけ可能であるが,&thinsp;メビウスの帯やのクライン・ボトルは向きづけ不可能であることが知られている. &thinsp;

# %% [markdown]
# # &thinsp; コホモロジー
# &emsp;ホモロジーの双対の概念としてコホモロジーがある. &thinsp;コホモロジーは多様体の向きづけ可能性を議論する際によく使用される概念である. &thinsp;大雑把に言うと単体複体内の単体を線形(準同型)写像として捉え直したことで得られるベクトル空間である. &thinsp;
# &emsp;本論文の目的であるホイットニー類のパーシステント化をする際にもやはりこのコホモロジーを使用する. &thinsp;しかしコホモロジーはホモロジーに比べてやや抽象度が高い. &thinsp;そこでこの章ではコホモロジーの定義について述べた後,&thinsp;それが前述したホモロジーとどのような関係性を持つのかについても記述する. &thinsp;

# %% [markdown]
# ## &thinsp; コホモロジー群
# &emsp;コホモロジー群の定義に入る前に幾つかの準備を行う. &thinsp;

# %% [markdown]
# #### 定義
# $V$を$\mathbb{Z}_2$上のベクトル空間とし,$\hom(V, \mathbb{Z}_2 )$を$V$から$\mathbb{Z}_2$への線型写像全体の集合とする. &thinsp;$\hom(V, \mathbb{Z}_2 )$上に加法$f + g$とスカラー倍$cf$を
# $$(f + g)(v) := f(v) + g(v) \\ (cf)(v) := cf(v)$$
# で定義する. &thinsp;ただしここで$f,g \in \hom(V, \mathbb{Z}_2 ),c \in \mathbb{Z}_2, v \in V$としている. &thinsp;この加法とスカラー倍によって$\hom(V, \mathbb{Z}_2 )$は$\mathbb{Z}_2$上のベクトル空間になる. &thinsp;以降,$\hom(V, \mathbb{Z}_2 )$をベクトル空間$V$の**双対**と呼ぶことにする. &thinsp;

# %% [markdown]
# #### 命題
# $m$次元ベクトル空間$V$の基底を$v_1, \cdots, v_m$として,&thinsp;これに対する$v_1^*, \cdots, v_m^* \in \hom (V, \mathbb{Z}_2)$を
# $$v_i^* (v_j) = \delta_{ij}  \ \ \ (0 \leq i, j \leq m)$$
# となる線型写像として定義する. &thinsp;ここで$\delta_{ij}$はクロネッカーのデルタである. &thinsp;このとき$v_1^*, \cdots, v_m^* $は$\hom (V, \mathbb{Z}_2)$の基底をなす. &thinsp;

# %% [markdown]
# $proof)$基底であることを示すには一次独立な生成系であることを示せば良い. &thinsp;\
# &emsp;まずは$v_1^*, \cdots, v_m^* $が$\hom(V, \mathbb{Z}_2)$を生成することをみる. &thinsp;そのために$f \in \hom(V, \mathbb{Z}_2)$を任意とする. &thinsp;$v \in V$とすると,$v_1, \cdots, v_m$は$V$の基底であるから,&thinsp;ある$c_1, \cdots, c_m \in \mathbb{Z}_2$によって$v = c_1 v_1 + \cdots + c_m v_m$と書くことができる. &thinsp;$f$は線形であるから
# $$f(v) = c_1f(v_1) + \cdots + c_m f(v_m)$$
# となる. &thinsp;一方で$v_i^*$も線形であるから同様の式を満たすが,$v_i^*$の定義と合わせることで
# $$v_i^*(v) = c_i$$
# がわかる. &thinsp;$c^*_i:= f(v_i) \in \mathbb{Z}_2$とおくと,
# $$f(v) = c_1^* v_1^*(v) + \cdots + c_m^* v_m^*(v)$$
# を得る. &thinsp;$v \in V$は任意だったため,&thinsp;以上により$v_1^*, \cdots, v_m^* $は$\hom(V, \mathbb{Z}_2)$を生成することがわかる. &thinsp;\
# &emsp;最後に$v_1^*, \cdots, v_m^* $が$\hom(V, \mathbb{Z}_2)$上一次独立であることを示す. &thinsp;そのために$c_1^*, \cdots, c_m^* \in \mathbb{Z}_2$が
# $$\boldsymbol{0} = c_1^* v_i^*+ \cdots + c_m^* v_m^*$$
# を満たすと仮定する. &thinsp;なおこの等式は写像としての等式であり,&thinsp;左辺の$\boldsymbol{0}$は$V$から$\boldsymbol{0} \in \mathbb{Z}_2$への定値写像を意味している. &thinsp;両辺の写像に各$v_i$における値を考えることで
# $$ \boldsymbol{0} = c_i^*$$
# を得る. &thinsp;従って$v_1^*, \cdots, v_m^* $が$\hom(V, \mathbb{Z}_2)$上一次独立である. &thinsp;\
# &emsp;以上により$v_1^* \cdots, v_m^* $は$\hom(V, \mathbb{Z}_2)$の基底をなすことが示された. &thinsp;$\square$

# %% [markdown]
# #### 系
# $\mathbb{Z}_2$上のベクトル空間$V$はその双対に線形同型である. &thinsp;$V \simeq \hom (V, \mathbb{Z}_2)$

# %% [markdown]
# #### 定義
# 命題2. &thinsp;1. &thinsp;2の基底$v_1^* \cdots, v_m^*$を,$V$の基底$v_1, \cdots, v_m$に対する**双対基底**という. &thinsp;

# %% [markdown]
# #### 定義
# 単体複体$K$に対する$q$次元鎖群$C_q(K)$の双対を$C^q(K)$と書いて,$K$の$q$**次元双対鎖群**という. &thinsp;さらに$\partial_{q + 1}:C_{q + 1}(K) \longrightarrow C_{q}(K)$を境界準同型とするとき,**$q$次元双対境界準同型** $\delta_q:C^q(K) \longrightarrow C^{q + 1}(K)$を
# $$\delta_q(f) = f \circ \partial_{q + 1} \ \ (f \in C^q(K))$$
# によって定義する. &thinsp;
# $\partial_{q} \circ \partial_{q + 1} = \boldsymbol{0}$だから
# $$\delta_{q} \circ \delta_{q - 1} = \boldsymbol{0}$$
# が成り立つ. &thinsp;つまり$Z^q(K) = Ker \delta_q \ \ , B^q(K) = Im \delta_{q - 1}$とすると
# $$B^q(K) \subset Z^q(K)$$
# が成り立つ. &thinsp;\
# そこで$q$**次元コホモロジー群**$H^q(K)$を以下で定義する. &thinsp;
# $$H^q(K) := Z^q(K)/B^q(K)$$

# %% [markdown]
# &emsp;1章では相対ホモロジーを導入したが,&thinsp;同じようにコホモロジーに対しても相対コホモロジーを考えることができる. &thinsp;これはいわば相対ホモロジーの双対である. &thinsp;

# %% [markdown]
# #### 定義
# 相対鎖群$C_q(K, L)$から$\mathbb{Z_2}$への準同型写像全体の集合を$C^q(K, L)$と書く. &thinsp;$\partial_q^*:C_q(K, L) \longrightarrow C_{q - 1}(K, L)$を相対鎖群の境界準同型とするとき,&thinsp;その双対境界準同型$\delta_q^*:C^q(K, L) \longrightarrow C^{q + 1}(K, L)$を
# $$\delta_q^*(f) : = f \circ \partial_{q + 1}^* \ \ \ (f \in C^q(K, L))$$
# で定義する. &thinsp;$\partial_q^*\circ \partial_{q + 1}^* = \boldsymbol{0}$であるから,$\delta_{q} ^* \circ \delta_{q - 1}^*= \boldsymbol{0}$である. &thinsp;つまり
# $$Im \ \delta_{q - 1}^* \subset \ker  \delta_{q}^*$$
# が成り立つ. &thinsp;そこで相対コホモロジー群$H^q(K, L)$を
# $$H^q(K, L) := \ker  \delta_{q}^*/ Im \delta_{q - 1}^*$$
# で定義する. &thinsp;

# %% [markdown]
# &emsp;次にこのコホモロジー群とホモロジー群の関係性について述べている二つの定理について記述する. &thinsp;後々の議論のため定理内ではホモロジーもコホモロジーも相対になっているが,$L = \emptyset$とすることで通常のホモロジーとコホモロジーの間にも成り立つ定理である. &thinsp;

# %% [markdown]
# #### 定理
# (普遍係数定理)
# 相対コホモロジー群$H^q(K, L)$は相対ホモロジー群の双対$\hom(H_q(K, L), \mathbb{Z}_2)$と同型である. &thinsp;

# %% [markdown]
# $proof)$二つの線形写像$\phi:H^q(K, L) \longrightarrow \hom(H_q(K, L), \mathbb{Z}_2)$と$\psi:\hom(H_q(K, L), \mathbb{Z}_2)\longrightarrow H^q(K, L)$を構成して$\psi \circ \phi$と$\phi \circ \psi$が共に恒等写像であることを示す. &thinsp;

# %% [markdown]
# ($\phi$の構成\)
#     コホモロジー類$[f] \in H^q(K, L)$に対して$\phi([f]) \in \hom(H_q(K, L), \mathbb{Z}_2)$を次で定義する. &thinsp;
#     $$\phi([f])([z]) :=  f(z)$$
#     この$\phi([f])$は見かけ上代表元の取り方に依存している. &thinsp;$\phi([f])$がホモロジー群から$\mathbb{Z}_2$への写像として矛盾なく定義されるには,
#     $$f \sim g , z \sim z' \ (f, g \in \ker  \delta_{q}^*, z, z' \in \ker  \partial_q^*) \Longrightarrow f(z) = g(z')$$
#     となることを確認する必要がある. &thinsp;ところがこれは,&thinsp;それぞれの同値関係の定義から$f - g = \delta_{q - 1}^* (h), z - z' = \partial_{q + 1}^*(c) \ (h \in C^{q - 1} (K, L), c \in C_{q + 1}(K, L))$とおくと
#     $$f(z) - g(z') = (f(z) - g(z)) +( g(z) - g(z')) \\ = (f - g)(z) + g(z - z') \\ = \delta_{q - 1}^* (h)(z) + g(\partial_{q + 1}^*(c)) \\ = h(\partial_q^*(z)) + \delta_q^*(g)(c) \\ = \boldsymbol{0}$$
#     が得られることから明らかである. &thinsp;従って$\phi([f])$は$f$の同値類によってのみ決定される写像$\phi([f]):H_q(K, L) \longrightarrow \mathbb{Z}_2$であり,&thinsp;定義から明らかに$H_q(K, L)$上線形であるから$\phi([f]) \in \hom(H_q(K, L), \mathbb{Z}_2)$が確かにわかる. &thinsp;また
#     $$\phi([f] + [g]) = \phi([f]) + \phi([g]) \\ \phi(c[f]) = c\phi([f]) \ \ (c \in \mathbb{Z}_2)$$
#     であることも$\phi([f])$の定義から確認できる. &thinsp;\
#     以上によって線型写像$\phi:H^q(K, L) \longrightarrow \hom(H_q(K, L), \mathbb{Z}_2)$が構成された. &thinsp;

# %% [markdown]
# ($\psi$の構成\)
#     $C_q(K, L)$はベクトル空間で$\partial_q^*:C_q(K, L) \longrightarrow C_{q - 1}(K, L)$は線形写像であるから, &thinsp; 線形代数における一般論より,&thinsp;ある部分空間$W$が存在して
#     $$C_q(K, L) = \ker  \partial_q^* \oplus W$$
#     と直和分解され$\eta := \partial^*_q | _W : W \longrightarrow Im \partial^*_q$が同型写像となる. &thinsp;そこで$F \in \hom(H_q(K, L), \mathbb{Z}_2)$に対して,&thinsp;写像$h_F:C_q(K, L) \longrightarrow \mathbb{Z}_2$を,$c = z + w \in C_q(K, L) \ (z \in \ker  \partial_q^*, w \in W)$に対して
#     $$ h_F(c) := F([z])$$
#     と定義する. &thinsp;$h_F$は$c \in C_q(K, L)$に関して線形であるから$h_F \in C^q(K, L)$であり,&thinsp;特に$c \in C_{q + 1}(K, L)$とすると
#     $$\delta_q^*(h_F)(c) = h_F (\partial_{q +1}^*(c)) = F([\partial_{q +1}^*(c)]) = F(\boldsymbol{0}) = \boldsymbol{0}$$
#     となるから$\delta_q^*(h_F) = \boldsymbol{0}$つまり$h_F \in \ker \delta_q^*$となる. &thinsp;そこで目的の写像$\psi:\hom(H_q(K, L), \mathbb{Z}_2)\longrightarrow H^q(K, L)$を
#     $$\psi(F) := [h_F]$$
#     で定義する. &thinsp;$h_F$の定義から明らかに$\psi$は$F \in \hom(H_q(K, L), \mathbb{Z}_2)$に関して準同型である. &thinsp;

# %% [markdown]
# ($\psi \circ \phi$が恒等写像であること\)
#     $[f] \in H^q(K, L)$とする. &thinsp;$\psi \circ \phi ([f]) = [h_{\phi([f])}]$に注意すると,$f \sim h_{\phi([f])}$を示せば良い. &thinsp;$c = z + w \in C_q(K, L) \ (z \in \ker  \partial_q^*, w \in W)$とすると
#     $$f(c) - h_{\phi([f])}(c) = f(c) - \phi([f])([z])  \\  = f(c) - f(z) = f(c - z)  = f(w)   \\ = f \circ \eta^{-1} \circ \eta(w)  = f \circ \eta^{-1}(\partial_q^*(w)) \ \ (\because \eta(w) = \partial_q^*(w)) \\ = f \circ \eta^{-1}(\partial_q^*(c)) \ \ (\because \partial_q^*(c) = \partial_q^*(w)) \\ = f^*(\partial_q^*(c)) \ \ (\because f^*|_{Im \partial_q^*} = f \circ \eta^{-1}) \\ =\delta_{q - 1}^*(f^*)(c)$$
#     従って$f - h_{\phi([f])} = \delta_q^*(f^*)$となる. &thinsp;ただし,&thinsp;ここで線形写像$f^*:C_{q - 1}(K, L) \longrightarrow \mathbb{Z}_2$は,&thinsp;線形写像$f \circ \eta^{-1}:Im \partial_q^* \longrightarrow \mathbb{Z}_2$をベクトル空間の直和分解$C_q(K, L) = Im \partial_q^*\oplus V$に対して,$f^*|_{Im \partial_q^*} = f \circ \eta^{-1}, f^*(V) = \boldsymbol{0}$と拡張したものとしている. &thinsp;以上の式変形によって$f \sim h_{\phi([f])}$が成り立つ. &thinsp;

# %% [markdown]
# $\phi \circ \psi$が恒等写像であること\)
#     $F \in \hom(H_q(K, L), \mathbb{Z}_2)$とする. &thinsp;$\phi \circ \psi(F) = \phi([h_F])$より$\phi([h_F]) = F$を示せば良い. &thinsp;$[z] \in H_q(K, L)$に対して$\phi([h_F])([z]) = h_F(z) = F([z])$だから確かに$\phi([h_F]) = F$が成り立つ. &thinsp;
#
# 以上の議論から題意が示された. &thinsp;$\square$

# %% [markdown]
# #### 系
# $\mathbb{Z}_2$係数においてはホモロジーとコホモロジーは同型である. &thinsp;
# $$H_k(K) \simeq H^k(K)$$

# %% [markdown]
# #### 定義
# $f:H_k(L) \longrightarrow H_k(K)$を準同型とする. &thinsp;普遍係数定理により$H^k(K) \simeq \hom (H_k(K), \mathbb{Z}_2)$とみなすことで,&thinsp;各コホモロジー類$r \in H^k(K)$は線形写像$r: H_{k}(K) \longrightarrow \mathbb{Z}_2$として扱える. &thinsp;従って準同型$f^*:H^k(K) \longrightarrow H^k(L)$が次のように定義される. &thinsp;
# $$f^*(r) :=r \circ f \ \ ( r \in H_k(K))$$
# この$f^*$を**$f$に対するコホモロジーの誘導準同型**という. &thinsp;

# %% [markdown]
# ## &thinsp; 積

# %% [markdown]
# #### 定義
# $p$次元双対鎖$c \in C^p(K )$と$q$次元双対鎖$d \in C^q(K )$に対して$c \smile d \in C^{p + q}(K )$を得る操作を**カップ積**と言い,&thinsp;以下で定義する. &thinsp;
# $$(c \smile d)(\langle a_0, \cdots, a_{p + q} \rangle) := c(\langle a_0, \cdots , a_p \rangle) \cdot d(\langle a_{p}, \cdots , a_{p+q} \rangle )$$
# このとき
# $$\delta_{p + q}(c \smile d) = (\delta_{p} c) \smile d + c \smile \delta_q d$$
# を満たすからこれによってコホモロジー類同士のカップ積$H^p(K ) \times H^q(K ) \longrightarrow H^{p + q}(K )$が矛盾なく定義される. &thinsp;
# $$\lbrack z \rbrack \smile \lbrack z' \rbrack =\lbrack z \smile  z' \rbrack$$

# %% [markdown]
# #### 定義
# $p + q$次元鎖$c \in C_{p+q}(K )$と$f \in C^p(K )$に対して,&thinsp;その**キャップ積**$c \frown f \in C_q(K )$を以下で定義する. &thinsp;
# $$ g(c \frown f) := (f \smile g)(c)  \ \ , g \in C^q(K )$$
# キャップ積は以下の性質を持つ. &thinsp;
# $$\partial (c \frown f) = \{(\partial c \frown f) - c \frown \delta f\} $$
# これによってホモロジー類とコホモロジー類のカップ積$H_{p + q}(K ) \times H^p(K ) \longrightarrow H_{q}(K )$が矛盾なく定義される. &thinsp;
# $$\lbrack z \rbrack \frown \lbrack f \rbrack =\lbrack z \frown f \rbrack$$
#
# <!-- 加群の係数の環として$\mathbb{Z}$を用いたが,$\mathbb{Z}/2\mathbb{Z}$としても同様の議論が可能である. &thinsp;以下では$\mathbb{Z}/2\mathbb{Z}$を係数とする場合は$C_*(K \mathbb{Z}/2)$などと表す. &thinsp;ホモロジー群や双対鎖群,コホモロジー群についても同様である. &thinsp; -->

# %% [markdown]
# #### 定理
# 弧状連結で向づけ可能な$n$次元ホモロジー多様体$M$に対し
# $$H^q(M) \simeq H_{n - q}(M) \ \ (q = 0, 1, \cdots)$$
# であり,&thinsp;その同型写像$l_q:H^q(M) \simeq H_{n - q}(M)$はキャップ積と$M$の基本ホモロジー類$[M]$を用いて
# $$l_q([f]) = [M] \frown [f]$$
# で与えられる. &thinsp;

# %% [markdown]
# ## &thinsp; ホイットニー類

# %% [markdown]
# #### 定義
# $E, B$を位相空間として,$\pi: E \longrightarrow B$を連続な全射とする. &thinsp;今,&thinsp;任意の$b_0 \in B$に対して次の$(i),(ii)$を満たすとき,$\xi = (E, B,\pi)$をベクトル束という. &thinsp;\
# $(i) F_{b_0}(\xi ) := \pi^{-1} (b_0)$は体$\mathbb{R}$上のベクトル空間である. &thinsp;\
# $(ii) b_0$における$B$のある開近傍$U \subset B$と同相写像$h:U \times \mathbb{R}^n \longrightarrow \pi^{-1}(U)$が存在して,&thinsp;対応
# $$\mathbb{R}^n \ni x \longmapsto h(b, x) \in F_b(\xi)$$
# が各$b \in U$においてベクトル空間としての同型を与える. &thinsp;
# $E$をベクトル束の全空間,$B$を底空間,$\pi$を射影といい$E(\xi), B(\xi), \pi_\xi$などと書く. &thinsp;また$(ii)$の$(U,h)$を$b$のまわりの$\xi$に対する局所座標系という. &thinsp;

# %% [markdown]
# #### 例
# 多様体$M$上の接束$TM$はベクトル束である. &thinsp;

# %% [markdown]
# #### 例
# 実射影空間$P^n = \{\{x, -x \}| x \in S^n \}$を底空間とする**直線束**と呼ばれるベクトル束$\gamma _n^1 = (E, P^n, \pi)$は次のように定義される. &thinsp;
# $$F_{\{x, -x\}}(\gamma_n^1)= \{(\{x, -x\}, \lambda x)|  \lambda \in \mathbb{R} \}\\ E = \bigcup_{b \in P^n}F_b(\gamma_n^1) \\ \pi(F_b(\gamma_n^1)) = b$$

# %% [markdown]
# #### 定義
# 全空間の間の連続写像$f:E(\xi) \longrightarrow E(\eta)$が,&thinsp;各$F_b(\xi)$に対してある$F_{b'}(\eta)$と線型同型を与えるとき,$f$を**束写像**という. &thinsp;$\hat f(b) = b'$とすると$f$は連続写像$\hat f: B(\xi) \longrightarrow B(\eta)$を与える. &thinsp;

# %% [markdown]
# #### 定義
# $\xi = (E, B, \pi)$をベクトル束とする. &thinsp;底空間の部分集合$B' \subset B$を取ると,$B'$上に$E' := \pi^{-1}(B')$を全空間とし$\pi' := \pi|_{E'}$を射影とするベクトル束$(E', B', \pi')$が構成される. &thinsp;これを$\xi|{B'}$と書いて$\xi$の$B'$への**制限**という. &thinsp;

# %% [markdown]
# #### 定義
# $\xi = (E, B, \pi)$をベクトル束とし,&thinsp;勝手な位相空間$B'$から$B$への連続写像を$f:B' \longrightarrow B$とする. &thinsp;このとき,$B'$を底空間とするベクトル束$f^*\xi = (E', B', \pi')$が次のようにして構成できる:
# $$E' := \{(b, e) \in B' \times E|f(b) = \pi(e) \} \\ \pi'(b, e) := b \ \ \ \ \ (b, e) \in E'$$
# ただしここでファイバー$F_b(f^* \xi)$上のベクトル空間としての演算は
# $$\lambda(b, e_1) + \mu(b, e_2) :=  (b, \lambda e_1 + \mu e_2) \ \ \ (\lambda , \mu  \in \mathbb{R})$$
# と定義する. &thinsp;こうしてできたベクトル束$f^*\xi$を**誘導束**という. &thinsp;なお,&thinsp;定義2. &thinsp;3. &thinsp;1の$(ii)$(局所自明性という）は以下のようにして確認できる:\
# $b_0 \in B'$とし$(U, h)$を$f(b_0)$のまわりの$\xi$に対する局所座標系とする. &thinsp;$U' := f^{-1}(U)$とするとこれは$b_0$の$B'$における開近傍である. &thinsp;そこで
# $$h': U' \times \mathbb{R}^n \longrightarrow \pi'^{-1}(U')$$
# を$h'(b, x) := (b, h(f(b), x))$で定義すると$(U', h')$が求める$b_0$の局所座標系となる. &thinsp;

# %% [markdown]
# #### 定義
# $\xi_1 = (E_1, B_1, \pi_1),\xi_2 = (E_1, B_2, \pi_2)$をベクトル束とする. &thinsp;このとき$E_1 \times E_2$を全空間,$B_1 \times B_2$を底空間,&thinsp;$\pi_1 \times \pi_2$を射影とするベクトル束$\xi_1 \times \xi_2$が構成できる. &thinsp;これを$\xi_1$と$\xi_2$の**直積束**という. &thinsp;

# %% [markdown]
# #### 定義
# 底空間が同じ$B$である二つのベクトル束を$\xi, \eta$とする. &thinsp;$d(b) := (b, b)$で定義される対角線写像$d:B \longrightarrow B \times B$は連続である. &thinsp;よって$B$上にベクトル束$d^*(\xi \times \eta)$が構成されるが,&thinsp;これを$\xi$と$\eta$のホイットニー和といい$\xi \oplus \eta$と書く. &thinsp;なおホイットニー和の各ファイバー$F_b(\xi \oplus \eta)$は標準的に$F_b(\xi) \oplus F_b(\eta)$に同型である. &thinsp;

# %% [markdown]
# #### 定義
# ベクトル束$\xi$に対し,&thinsp;以下の4つの公理を満たすコホモロジー類を**ホイットニー類**という. &thinsp;
#
# $(i)w_i(\xi) \in H^i(B(\xi)) (w_0(\xi) = 1,\ i = 0, 1, \cdots )$
#
# $(ii)$束写像から定まる連続写像$f:B(\xi)  \longrightarrow B(\eta)$に対して$w_i(\xi) = w_i(f^*\eta)$
#
# $(iii)\xi, \eta \ (B(\xi) = B(\eta)) \ \Longrightarrow \ w_k(\xi \oplus \eta) = \sum_{i} w_i(\xi) \smile w_{k - i}(\eta)$
#
# $(iv)$円周$P^1$上の直線束$\gamma_1^1$に対して$w_i(\gamma_1^{1}) \ne \boldsymbol{0}$
# ホイットニー類は一意的に存在する. &thinsp;

# %% [markdown]
# #### 例
# 多様体$M$に対して,$M$が向きづけ不可能であることと,$1$次元ホイットニー類$w_1(TM) \in H^1(M)$が$\boldsymbol{0}$であることと,$M$が向きづけ不可能であることは同値である. &thinsp;また,&thinsp;このとき$w_1(TM) \in H^1(M)$の双対として,$w_1(TM)^* \in H_1(M)$が取れる(普遍係数定理). &thinsp;

# %% [markdown]
# # &thinsp; パーシステント$\cdot $(コ)ホモロジー
# &emsp;あるパラメータ(例えば時間)によって単体複体が増大していく際,&thinsp;その多面体内の穴が,&thinsp;ある時刻で生まれてさらに進んだ時刻で消えるといった現象が観察される. &thinsp;パーシステントホモロジーはそういった現象をホモロジー群の生成元によって記録するものである. &thinsp;\
# &emsp;しかし,&thinsp;通常のパーシステントホモロジーは向き付け可能性の可否を判別することはできていない. &thinsp;本論文ではこの問題を解消するために,&thinsp;パーシステント性をコホモロジーのレベルに発展させたパーシステントコホモロジーおよびパーシステントホイットニー類を構成する. &thinsp;

# %% [markdown]
# ## &thinsp; 構造定理

# %% [markdown]
# #### 定理
# $F = \oplus_{i = 1}^{m}( x^d_i)$の斉次部分加群$H \subset G \subset F$の階数を$n, m$とする. &thinsp;このとき$s \in \mathbb{Z}_{\geq 0}$と自然数$l_1 \leq \cdots, \leq l_s$が存在して剰余加群$G / H$は$G$のある斉次基底$g_1, \cdots, g_m$を用いて
# $$G / H = \bigoplus_{i = 1}^{s} \langle [g_i] \rangle \oplus  \bigoplus_{i = n + 1}^{m} \langle [g_i]  \\ \text{Ann}([g_i]) = (x^{l_i}), \ i = 1, \cdots, s \\ \text{Ann}([g_i]) = 0, \ i = n + 1, \cdots, m$$
# と表せる. &thinsp;ここで$s = 0$のときは$\text{Ann}([g_i]) \ne 0 $となる成分は表れない. &thinsp;なお$\text{Ann}(m) := \{f \in \mathbb{Z}_2[x]| f \cdot m = 0 \}$は$m$の**零化イデアル**という

# %% [markdown]
# #### 定理
# $M = \oplus_{i \geq 0} M_i$を有限生成次数付き$\mathbb{Z}_2[x]$加群とする. &thinsp;このとき$M$は次数付き$\mathbb{Z}_2[x]$加群としての同型
# $$M \simeq \bigoplus_{i = 0}^{s} \left( (x^{d_i}) / (x^{d_i + l_i}) \right ) \oplus \bigoplus_{i = s + 1}^{s + r}(x^{d_i})$$
# の形に表せる. &thinsp;さらに$d_i, l_i, s, r$は$M$の次数付きの同型類から一意に決まる. &thinsp;

# %% [markdown]
# ## &thinsp; パーシステントホモロジー

# %% [markdown]
# #### 定義
# 集合列$\{A_i\}_{i = 0}^{\infty}$が単調増加であるとき&thinsp;つまり
# $$A_0 \subset A_1 \subset \cdots $$
# が成り立つとき,$\{A_i\}_{i = 0}^{\infty}$をフィルトレーションという. &thinsp;. &thinsp;フィルトレーションにおいては添字$i$は**時刻**と呼ばれる. &thinsp; またある非負整数$\theta$が存在して$i \geq \theta $なら$A_i = A_{\theta}$が成り立つとき,&thinsp;フィルトレーション$\mathbb{A}$は**有限型**であるといい,&thinsp;そのような$\theta$の内で最小のものを**飽和時刻**という. &thinsp; この論文では有限型のみを扱う. &thinsp;
# &emsp;以降でフィルトレーションを表す際は$\mathbb{A}$や$\mathbb{X}$のような二重線の白抜き文字を用いる. &thinsp;あるいは単調増加な関係性を明確にするために
# $$\mathbb{A}: A_0 \subset A_1 \subset \cdots $$
# のようにして表すこともある. &thinsp;仮にフィルトレーションを単に$\mathbb{A}$や$\mathbb{X}$と書いた場合フィルトレーションの$i$番目の要素(集合)を,$A_i$や$X_i$のように二重線を無くした通常の表記に添字をつけた記号で表すことにする. &thinsp;

# %% [markdown]
# #### 定義
# 単体複体のフィルトレーション$\mathbb{K}: K_0 \subset K_1 \subset \cdots $を考え,$K = \bigcup_{i \geq 0} K_i$とおく. &thinsp;$\sigma \in K$が時刻$t$で発生したとは$\sigma \in K_t -  K_{ t - 1}$を満たすことであり,&thinsp;このとき$T(\sigma) = t$と表す. &thinsp;

# %% [markdown]
# #### 例
# ヴィートリスリップス複体$VR_r(P)$からはパラメータ$r$に関するフィルトレーションが得られる. &thinsp;つまり$r < r'$なら$VR_r(P) \subset VR_{r'}(P)$が成り立つ. &thinsp;
# $P$は有限集合であるからこのフィルトレーションは有限型であり,&thinsp;有限個の対$(r, r')$を除いて$VR_r(P) =  VR_{r'}(P)$が成り立つ. &thinsp;したがってパラメータの列$0 = r_0< r_1< \cdots < r_\Theta$に対して有限型のフィルトレーション
# $$VR_{r_0}(P) \subset VR_{r_1}(P) \subset \cdots VR_{r_{\Theta}}(P )$$
# を得る. &thinsp;

# %% [markdown]
# #### 例
# ヴィートリスリップス複体の時と同様に$0 = r_0< r_1< \cdots < r_\Theta$に対してチェック複体の有限型のフィルトレーション
# $$C_{r_0}(P) \subset C_{r_1}(P) \subset \cdots C_{r_{\Theta}}(P )$$
# を得る. &thinsp;脈体定理によりチェック複体$C_r(P)$は$X_r = \bigcup_{x \in P}B(x, r)$にホモトピー同値である. &thinsp;

# %% [markdown]
# <!-- #### 定義
# 鎖群$C_k(K_t)$の直和$C_k(\mathbb{K}) = \bigoplus_{t \geq 0} C_k(K_t)$に,ダミー変数$x$との準同型な作用
# $$x \cdot (c_0 , c_1, \cdots) := (0, c_0,c_1, \cdots)$$
# を導入すると. &thinsp;$x C_k(K_t) \subset C_k(K_{t + 1})$となる. &thinsp;従って一般の$f,g \in \mathbb{Z}_2[x]$に対しては
# $$(f + g) \cdot (c_0 , c_1, \cdots) := f \cdot (c_0 , c_1, \cdots) + g \cdot (c_0 , c_1, \cdots) \\ (fg) \cdot (c_0 , c_1, \cdots) :=  f \cdot (g \cdot (c_0 , c_1, \cdots)) \\ 1 \cdot (c_0 , c_1, \cdots) = (c_0 , c_1, \cdots)$$
# と再帰的に定義することにより$C_k(\mathbb{K})$は次数付き$\mathbb{Z}_2[x]$加群となる. &thinsp;この$C_k(\mathbb{K})$をフィルトレーション$\mathbb{K}$に対する$k$鎖群という. &thinsp; -->
#
# <!-- &emsp;フィルトレーション$\mathbb{K}$における,$k$単体$\sigma$の発生時刻を$t = T(\sigma)$とするとき,
# $$ e_{\sigma} := (c_0, c_1, \cdots ), \ \ c_i := \begin{cases} \sigma & \text{if} \  i =t \\ 0 & \text{else} \end{cases}$$
# とおくと
# $$\Xi_k := \{ e_{\sigma} | \sigma \in K,  \dim \sigma = k \}$$
# は$k$鎖群$C_k(\mathbb{K})$の基底となる. &thinsp;なおフィルトレーションは有限型であるため$\Xi_k$は有限集合,従って$C_k(\mathbb{K})$は有限生成な次数付き自由$\mathbb{Z}_2[x]$加群である. &thinsp;
# &emsp;一般に階数$m$の次数付き自由$\mathbb{Z}_2[x]$加群$M$は,斉次基底を$\{ v_1, \cdots, v_m \}, ( \deg v_i = d_i, i = 1, \cdots, m)$とするとき,写像
# $$\varphi: M \ni (v_1, \cdots, v_m) \begin{pmatrix} x_1 \\  x_2 \\ \vdots \\ x_m  \end{pmatrix} \longrightarrow  (\boldsymbol{e}(d_1), \cdots, \boldsymbol{e}(d_m)) \begin{pmatrix} x_1 \\  x_2 \\ \vdots \\ x_m  \end{pmatrix} \in \bigoplus_{i = 0}^{m}\left( x^{d_i} \right)$$
# によって$\bigoplus_{i = 0}^{m}\left( x^{d_i} \right)$に同型になる. &thinsp; -->
#
# <!-- #### 定義
# フィルトレーション内の$k$単体$\sigma = \left | v_0, \cdots, v_k \right|$に対して$\sigma_i := \left | v_0, \cdots, v_{i - 1}, v_{i + 1}, \cdots, v_k \right | $とおくとき,境界準同型$\partial_k: C_k(\mathbb{K}) \longrightarrow C_{k - 1}(\mathbb{K})$を$C_k(\mathbb{K})$の基底$\Xi_k$に対して
# $$\partial_k e_{\sigma} := \sum_{i = 0}^{k} x^{T(\sigma) - T(\sigma_i)}e_{\sigma_i}$$
# と定義する. &thinsp;ただし$k = 0$のときは$\partial_0 := \boldsymbol{0}$と定義する. &thinsp;$\partial_k(C_k(K_t)) \subset C_{k - 1}(K_{t})$となるから$\partial_k$は次数付き準同型である. &thinsp; -->
#
# <!-- #### 命題
# 任意の$k \in \mathbb{N}$に対して$\partial_{k - 1} \circ \partial_{k} = 0$が成り立つ. &thinsp; -->
#
# <!-- $\partial_k$が次数付き準同型であることから$\ker \partial_k, Im \partial_k$は斉次部分加群であり,それぞれ直和分解
# $$\ker \partial_k = \bigoplus_{t \geq 0}\ker \partial_k^{t} \\ Im \partial_k = \bigoplus_{t \geq 0}Im \partial_k^{t} $$
# をもつ. &thinsp;ここで$\partial_k^{t} = \partial_k |_{K_t}$としている. &thinsp;また上記の命題から$Im \partial_{k + 1} \subset \ker \partial_k , Im \partial_{k + 1}^t \subset \ker \partial_k^t $が成り立つ. &thinsp;以上の準備の下,パーシステントホモロジー群$PH_k(\mathbb{K})$を次のように定義する. &thinsp; -->
#
# #### 定義
# 単体複体の有限型のフィルトレーション$\mathbb{K}$
# $$\mathbb{K}:  K_0 \subset K_1 \subset \cdots $$
# を考える. &thinsp;包含写像$\iota_t^{t + 1}:K_t \hookrightarrow K_{t + 1}$は単体写像であるから誘導準同型
# $$\iota_{t*}^{t + 1}:H_k(K_t) \longrightarrow H_k(K_{t + 1})$$
# が得られる. &thinsp;$PH_k(\mathbb{K})$をベクトル空間としての直和
# $$PH_k(\mathbb{K}) := \bigoplus_{t \geq 0}H_k(K_t)$$
# とおき,&thinsp;さらにシフト演算と呼ばれるダミー変数$x$と$e = (e_0,  e_1, \cdots ,e_t, \cdots) \in PH_k(\mathbb{K}) \ (e_t \in H_k(K_t))$との演算を
# $$x \cdot e = ( 0, \iota_{0*}^{1}(e_0),  \iota_{1*}^{2}(e_1), \cdots )$$
# で定義することで$PH_k(\mathbb{K})$は次数付き$\mathbb{Z}_2[x]$加群となる. &thinsp;フィルトレーションが有限型であったことから,$PH_k(\mathbb{K})$は有限生成である. &thinsp;この$PH_k(\mathbb{K})$を$k$**次元パーシステントホモロジー群**という. &thinsp;

# %% [markdown]
# &emsp;構造定理を用いるとパーシステントホモロジーは斉次基底$g_1, \cdots , g_m$を用いて
# $$PH_k(\mathbb{K})  = \bigoplus_{i = 1}^{s} \langle [g_i] \rangle \oplus  \bigoplus_{i = n + 1}^{m} \langle [g_i] \rangle \\ \text{Ann}([g_i]) = (x^{l_i}), \ i = 1, \cdots, s \\ \text{Ann}([g_i]) = 0, \ i = n + 1, \cdots, m$$
# と表すことができる. &thinsp;  この表示において$d_i = \deg g_i$とし$[g_i] \in PH_k(\mathbb{K})$に対応する$H_k(K_{d_i})$のホモロジー類を$[h_i]$とする. &thinsp;

# %% [markdown]
# &emsp;$ i = 1, \cdots, s $に対しては零化イデアルの定義から$0 \leq l < l_i, $のときは$\iota_{d_i*}^{d_i + l}([h_i])  \ne 0 $であり,$\iota_{d_i*}^{d_i + l_i}([h_i]) = 0$となることがわかる. &thinsp;つまり区間$[d_i, l_i)$は$k$次元サイクル$h_i$の存続期間となる. &thinsp;一方で$i = n + 1, \cdots m$に対しては$\text{Ann}([g_i]) = 0$であるから$h_i$は$d_i$で発生して以降は飽和時刻まで存在することがわかる. &thinsp;そこでパーシステント区間が上記の表示を用いて次のように定義される. &thinsp;

# %% [markdown]
# #### 定義
# $$I_i = \begin{cases} [d_i, d_i + l_i), & i = 1, \cdots, s \\ [d_i, \Theta] & i = n + 1, \cdots, m\end{cases}$$
# を **パーシステント区間**という. &thinsp;ここで$\Theta$はフィルトレーションの飽和時刻である. &thinsp;また$d_i$を区間$I_i$の**発生時刻**(birth),$d_i + l_i$を**消滅時刻**(death)という. &thinsp;この意味で$I_i(b) = d_i, I_i(d) = d_i + l_i$などと表す. &thinsp;

# %% [markdown]
# #### 定義
# $$PD_k(\mathbb{K}) = \{(I_i(b), I_i(d)) \in \mathbb{R}^2 | i = 1, \cdots, s + r\}$$
# を**パーシステント図**という. &thinsp;

# %% [markdown]
# ## &thinsp; パーシステントコホモロジー

# %% [markdown]
# &emsp;$\mathbb{K}: K_0 \subset K_1 \subset \cdots $を単体複体の有限型のフィルトレーションとし,&thinsp;その飽和時刻を$\Theta$とする. &thinsp;

# %% [markdown]
# #### 定義
# ベクトル空間としてのコホモロジーの直和を
# $$PH^k(\mathbb{K}) := \bigoplus_{0 \leq t}H^k(K_t)$$
# とする. &thinsp;ダミー変数$y$と$r = (r_0, r_1, \cdots, ) \in PH^k(\mathbb{K})$とのシフト演算を
# $$y \cdot r := (\iota_{0}^{ 1 *}(r_{1}), \iota_{1}^{2 *}(r_{2}),\cdots)$$
# で定義すると,$PH^k(\mathbb{K})$は次数付き$\mathbb{Z}_2[y]$加群となる. &thinsp;この$PH^k(\mathbb{K})$を**$k$次元パーシステントコホモロジー群**と言う. &thinsp;
# ここで$\iota_t^{t + 1 *}$はホモロジー群の誘導準同型$\iota_{t_*}^{t + 1}: H_k(K_{t}) \longrightarrow H_k(K_{t + 1})$に対するコホモロジー群の誘導準同型
# $$\iota_t^{t + 1 *}: H^k(K_{t + 1}) \longrightarrow H^k(K_t)$$
# である. &thinsp;
# <!-- そこで$r = (\cdots, r_{\Theta - 1} r_{\Theta}) \in PH^k(\mathbb{K}) \ \ (r_t \in H^k(K_t))$とダミー変数$x$との演算を次のように定義する. &thinsp;
# $$x \cdot r := (\cdots, \iota_{\Theta - 2}^{\Theta - 1 *}(r_{\Theta - 1}), \iota_{\Theta - 1}^{\Theta *}(r_{\Theta}), 0 )$$
# このとき$r' \in PH^k(\mathbb{K})$とすると
# $$x \cdot (r + r') = x \cdot r + x \cdot r'$$
# が成り立つ. &thinsp;ここでさらに$f, g \in \mathbb{Z}_2[x]$に対して再帰を用いて
# $$1 \cdot r = r$$
# $$(f g) \cdot r := f \cdot (g \cdot r)$$
# $$(f + g) \cdot r := f \cdot r + g \cdot r$$
# と定義すると,$PH^k(\mathbb{K})$は次数付き$\mathbb{Z}_2[x]$上の加群となる. &thinsp; -->

# %% [markdown]
# &emsp;普遍係数定理により各$t$においてベクトル空間として$H^k(K_t) \simeq H_k(K_t)$が成り立つから,&thinsp;パーシステントコホモロジー群$PH^k(\mathbb{K})$もベクトル空間として$PH_k(\mathbb{K})$に同型である. &thinsp;

# %% [markdown]
# <!-- #### 定義
# 同じ長さの２つのフィルトレーション
# $$\mathbb{X}: \emptyset = X_0 \subset X_1 \subset \cdots \subset X_m = X$$
# $$\mathbb{Y}: \emptyset = Y_0 \subset Y_1 \subset \cdots \subset Y_m = Y$$
# に対して,それぞれの包含写像を$\phi_i^{i + 1}: X_i \hookrightarrow X_{i + 1}, \psi_i^{i + 1}: Y_i \hookrightarrow Y_{ i + 1}$とする. &thinsp;今連続写像の族$f_i: X_i \longrightarrow Y_i$が存在して,
# $$\psi_i^{i + 1} \circ f_i = f_{i + 1} \circ \phi_{i}^{i + 1} \ \ ( i = 1, \cdots , m - 1)$$
# が成り立つとき,$f = \{f_i\}$を**フィルトレーションの間の連続写像**といい,$f: \mathbb{X} \longrightarrow \mathbb{Y}$と書くことにする. &thinsp;
#
# #### 命題
# 同じ長さの２つのフィルトレーション
# $$\mathbb{X}: \emptyset = X_0 \subset X_1 \subset \cdots \subset X_m = X$$
# $$\mathbb{Y}: \emptyset = Y_0 \subset Y_1 \subset \cdots \subset Y_m = Y$$
# から定まるパーシステントホモロジー群をそれぞれ$PH^q(\mathbb{X}) = \oplus H^q(X_i), PH^q(\mathbb{Y}) = \oplus H^q(Y_i)$とし,$\{f_i\}: \mathbb{X} \longrightarrow \mathbb{Y}$をフィルトレーションの間の連続写像とする. &thinsp;各$f_i$が引き起こすコホモロジーの間の準同型$f_i^*:H^q(Y_i) \longrightarrow H^q(X_i)$は各$r_{i + 1} \in H^q(Y_{i + 1})$に対して以下の性質を満たす. &thinsp;
# $$xf_{i + 1}^*(r_{i + 1}) = f_{i}^*(x r_{i + 1})$$
# $proof)\{f_i\}$はフィルトレーションの間の写像であるから$\psi_i^{i + 1} \circ f_i = f_{i + 1} \circ \phi_{i}^{i + 1} \ \ ( i = 1, \cdots , m - 1)$が成り立っている. &thinsp;ここで$\phi_i^{i + 1}: X_i \hookrightarrow X_{i + 1}$と$\psi_i^{i+1}: Y_i \hookrightarrow Y_{i + 1}$は包含写像である. &thinsp;$x$との演算の定義により$x r_{i+1} = (\psi_{i}^{i + 1})^*(r_{i + 1})$であることから
# $$f_{i}^*(x r_{i+1}) = f_{i}^*((\psi_{i}^{i + 1})^*(r_{i + 1})) = f_{i}^* \circ (\psi_{i}^{i + 1})^*(r_{i + 1}) = (\psi_{i}^{i + 1} \circ f_i)^*(r_{i + 1}) = ( f_{i + 1} \circ \phi_{i}^{i + 1})^*(r_{i + 1}) = (\phi_{i}^{i + 1})^* (f_{i + 1}^*(r_{i + 1})) = xf_{i + 1}^*(r_{i + 1})$$
# $\square$ -->
# <!--
# #### 定義
# 命題3. &thinsp;1. &thinsp;3の$\{f_i^*\}$をフィルトレーションの間の連続写像$f = \{f_i\}$から定まるコホモロジーの誘導準同型といい$f^*:H^q(\mathbb{Y}) \longrightarrow H^q(\mathbb{X})$と書く -->

# %% [markdown]
# ### &thinsp; パーシステントホイットニー類
# ここではホイットニー類のパーシステント性について定義する。ホイットニー類はベクトル束上で定義される概念であったが,&thinsp;これをパーシステントコホモロジーにおける概念に拡張するために幾つかの準備を行う. &thinsp;
#
# #### 定義
# $E$を全空間,$X$を底空間とするベクトル束$\xi = (E,X, \pi)$を考える. &thinsp;今飽和時刻$\Theta$において$X_{\Theta} = X$となるフィルトレーション
# $$\mathbb{X}:\emptyset \subset X_0 \subset X_1 \subset \cdots \subset X_{\Theta} = X$$
# を考えると,&thinsp;各$i\geq 1$に対して$X_i$を底空間に対する$\xi$の制限束$\xi|X_i = (E_i, X_i, \pi_i)$が定義される. &thinsp;また,&thinsp;さらに
# $$E_1 \subset \cdots \subset E_m = E$$
# が成り立つ. &thinsp;ベクトル束の系列$\xi|X_i(i = 1, \cdots, m)$を,&thinsp;フィルトレーション$\mathbb{X}$に関する**ベクトル束$\xi$のフィルトレーション**といい,&thinsp;記号$\xi|\mathbb{X}$と書くことにする. &thinsp;\
# &emsp;以降では,&thinsp;ベクトル束のフィルトレーションを単に$\xi|\mathbb{X}$と書いた場合は,$\xi|X_i$で$i$番目のベクトル束を表すものとする. &thinsp;ただし$\xi|X_\infty$は単純に$\xi$で表す. &thinsp;また$X$が単体複体$K$の多面体であるときはベクトル束のフィルトレーションを$\xi | \mathbb{K}$と書く. &thinsp;

# %% [markdown]
# <!-- #### 定義
# $X_{\infty} = X$であるようなフィルトレーション$\mathbb{X}$に関するベクトル束$\xi = (E, X, \pi)$のフィルトレーションを$\xi|\mathbb{X}$とする. &thinsp;さらに位相空間$Y$から$X$への写像を$f:Y \longrightarrow X$とする. &thinsp;このとき$f$によって$Y$を底空間とする誘導束$f^*\xi$を構成できるが,$Y_i := f^{-1}(X_i)$とすることで$\mathbb{X}$と同じ長さのフィルトレーション
# $$\mathbb{Y}: \emptyset = Y_0 \subset \cdots \subset Y_{\infty} = Y$$
# を得る. &thinsp;従ってベクトル束のフィルトレーション$f^*\xi|\mathbb{Y}$が構成される. &thinsp;これを$f$**が誘導するベクトル束**$\xi$**のフィルトレーション**あるいは単に**誘導束のフィルトレーション**と呼ぶことにする. &thinsp;定義から$f^*\xi|Y_i = f^*(\xi|X_i)$が成り立つことに注意. &thinsp; -->
#
# <!-- #### 定義
# 同じ底空間$X$上の二つのベクトル束を$\xi, \eta$とし,$X_{\infty} = X$であるようなフィルトレーションを$\mathbb{X}$とする. &thinsp;このとき,$X$上のホイットニー和$\xi \oplus \eta$が構成されることで$\mathbb{X}$に関するベクトル束のフィルトレーション$(\xi \oplus \eta)|\mathbb{X}$が得られる. &thinsp;これを二つのベクトル束のフィルトレーション$\xi|\mathbb{X}, \eta|\mathbb{X}$のホイットニー和という. &thinsp;また明らかに$(\xi \oplus \eta)|X_i = \xi | X_i \oplus \eta | X_i$が成り立っていることに注意. &thinsp;
#  -->
#
# <!-- #### 定義
# 同じ長さの２つのフィルトレーション
# $$\mathbb{X}: \emptyset = X_0 \subset X_1 \subset \cdots \subset X_m = X \\ \mathbb{Y}: \emptyset = Y_0 \subset Y_1 \subset \cdots \subset Y_m = Y$$
# において,$X, Y$を底空間とするベクトル束をそれぞれ$\xi, \eta$とする. &thinsp;この時,定義4. &thinsp;1. &thinsp;1よりそれぞれのフィルトレーションからベクトル束$\xi|\mathbb{X}, \eta|\mathbb{Y}$が構成される. &thinsp;
#  -->

# %% [markdown]
# #### 定義
# ベクトル束のフィルトレーション$\xi | \mathbb{X}$において$k$次ホイットニー類からなる$PH^k(\mathbb{K})$の元
# $$w_k(\xi | \mathbb{K}):=(\cdots, w_k(\xi | K_{\Theta - 1}), w_k(\xi | K_{\Theta}))$$
# をパーシステントホイットニー類という. &thinsp;
# <!-- を**$k$次パーシステントホイットニー類**という. &thinsp;包含写像からの誘導$\iota_{t}^{t + 1*}:H^k(K_{t + 1}) \longrightarrow H^k(K_{t})$を用いると
# $$w_k(\xi | K_{t - 1}) = \iota_{t - 1 }^{t*} (w_k(\xi | K_t))$$
# が成り立つから$w_k(\xi)$と$(\cdots, 0, w_k(\xi))$を同一視することで,
# $$w_k(\xi | \mathbb{K}) = \sum_{i \geq 0}x^i w_k(\xi) $$
# と表すことが出来る. &thinsp;なおフィルトレーションは有限型であるため$f := \sum_{i \geq 0}x^i $は$\mathbb{Z}_2[x]$の多項式である. &thinsp;$w_k(\xi) \ne 0$のとき,$f$の次数を$d$とするとき,区間$[d ,  \Theta]$がホイットニー類の存続区間てある. &thinsp;-->

# %% [markdown]
# &emsp;普遍係数定理より$PH^k(\mathbb{K})$は$\mathbb{Z}_2$上のベクトル空間として$PH_k(\mathbb{K})$に同型であるため,&thinsp;ベクトル空間としての同型写像$\rho: PH^k(\mathbb{K}) \longrightarrow PH_k(\mathbb{K})$を一つ固定するとき$\rho (w_k(\xi | \mathbb{K})) \in PH_k(\mathbb{K})$より,&thinsp;ホイットニー類をホモロジー類によって表すことができる. &thinsp;パーシステントホモロジー$PH_k(\mathbb{K})$が斉次元$r_1, \cdots , r_m (r_i \in H_k(K_i))$によって
# $$PH_k(\mathbb{K})  = \bigoplus_{i = 1}^{s} \langle r_i \rangle \oplus  \bigoplus_{i = n + 1}^{m} \langle r_i \rangle \\ \text{Ann}(r_i) = (x^{l_i}), \ i = 1, \cdots, s \\ \text{Ann}(r_i) = 0, \ i = n + 1, \cdots, m$$
# の表示を持つとき$\rho(w_k(\xi | \mathbb{K})) = \sum_{i} f_i r_i$と一意的に書くことができる. &thinsp;$w_k(\xi | K_\theta) \ne 0$のときは$i=n+1, \cdots, m$の内のある$i$に対しては$f_i \ne 0 $でなければならない。

# %% [markdown]
# ## &thinsp; 自然画像データのパーシステントホモロジー

# %% [markdown]
# &emsp;パーシステントホモロジーの応用先として,Mumfordによる自然の背景画像データの特徴付けに関する研究がある. &thinsp;一般に画像データは,&thinsp;数学的には高次元のベクトル空間$P$のベクトルとして扱うことができる. &thinsp;従って自然の背景画像の集合も高次元ベクトル空間のある部分集合$T$と見做せる. &thinsp;このことから,&thinsp;写真のデータセットがある多様体を近似していることを想定した研究が今までにいくつか行われてきた. &thinsp;しかしMumfordは別の手法をとった. &thinsp;それはデータセット内の各画像から$3 \times 3$のパッチをランダムにとり,&thinsp;そのパッチの空間を分析する方法である. &thinsp;このような手法を取った理由は画像の空間の次元にある. &thinsp;仮に自然の背景画像の集合がある多様体を近似していたとしても,$P$から任意に取ってきた画像が自然の画像である可能性は低いと考えられるため,$T$の次元も余次元もかなり高いことが予想され,&thinsp;結果的に空間全体の分析を行うのが難しくなる. &thinsp;そこでMumfordは代わりに$3 \times 3$のパッチの空間の局所的な特徴に関する研究を行った. &thinsp;その結果,$3 \times 3$のパッチが成す空間には高密度な2次元部分多様体が存在する十分な証拠が得られた. &thinsp; このMumfordらの観察を補強するかたちでCarlssonは同じようなパッチの空間とその部分集合に対して,&thinsp;多項式の空間によるパラメータ化を行い,&thinsp;結果としてクライン・ボトルと同相な2次元の部分集合がパッチの空間内に存在することの十分な傍証を得た. &thinsp; 以下ではその概要を示す. &thinsp;

# %% [markdown]
# ### &thinsp; $S^7$へのパッチの射影
# 収集された自然画像データから得られた画素のコントラストを表す $3 \times 3$のパッチの$4 \cdot 10^6$個の集まりを$M$とする.ひとつのパッチのマス目にはコントラストを表す実数値が載っている.これよりひとつのパッチは$9$次元ベクトルとして捉えられる.&thinsp; つまり$M$は$\mathbb{R}^9$上の点データクラウドである.
# <!--
# $\tilde{M}$の各パッチを取り出すために次のようなステップを踏む
#
# - $C$の写真内の$3 \times 3$パッチからなる大きな集合$L$をランダムに取る
# - $L$の各パッチを$9$次元ベクトル$\boldsymbol{x}$として見做す
# - パッチのベクトル$\boldsymbol{x} = [x_1, \cdots, x_9]^T$の各ピクセルに対数を取って新たな$9$次元ベクトル$\boldsymbol{y}$とする;$\boldsymbol{y} = [\log(x_1), \cdots, \log(x_9)]^T$
# - $\boldsymbol{y}$のコントラスト($D-norm$)を計算する. &thinsp;
# - $L$から得られた$\boldsymbol{y}$の内,$D-norm$の値が,$C$の写真から得られる$3 \times 3$パッチ全体の上位$20\%$内に含まれるようなパッチ全体を$L'$とする. &thinsp;
#
# - $L'$の各ベクトル$\boldsymbol{y}$を次のように正規化する. &thinsp;
# $$\frac{\boldsymbol{y} - m(\boldsymbol{y})\vec{1}}{\|\boldsymbol{y} - m(\boldsymbol{y})\vec{1}\|_{D}}$$
# ここで$m(\boldsymbol{y}) := \frac{1}{9} \sum_{i = 1}^{9}y_i, \vec{1} = (1, \cdots, 1)^T \in \mathbb{R}^9$としている. &thinsp;
# この正規化によって各パッチは$\tilde{S}^7 := \{ \boldsymbol{y} \in \mathbb{R}^9| m(y) = 0, \boldsymbol{y}^TD \boldsymbol{y} = 1\}$に射影される. &thinsp;
#
# - $\tilde{S}^7$を$S^7$に座標変換する;
# $\tilde{S}^7$の$D-norm$に関する正規直交基底として,以下のMumfordの基底をとり,
# <img src = "images/Mumford_basis. &thinsp;jpeg">
# $A = [\boldsymbol{e}_1, \cdots ,\boldsymbol{e}_8], \Lambda = diag(\frac{1}{\| \boldsymbol{e}_1 \|^2} , \cdots , \frac{1}{\| \boldsymbol{e}_8 \|^2})$として$\boldsymbol{v} = \Lambda A^T \boldsymbol{y}$によって$S^7$に座標変換する. &thinsp; -->

# %% [markdown]
# &emsp;$M$はスパースデータであり,&thinsp; [2]に従って以下のような正規化を通して$7$次元球面$S^7$上のデータと見なす.$P$を$2$変数実係数多項式全体とする. &thinsp;
# 1つのパッチの各ピクセルは$xy$平面上の点$(x_0, y_0) \in H := \{-1, 0, 1\}^2$として考えることができる. &thinsp;
# <div class = "pix-center">
#     <img src="images/pach_as_H.jpeg" height="70%" width="70%">
#     <p>各パッチ$x = [x_1, \cdots, x_9] \in \mathbb{R}^9$のマス目を$H$の要素に割り当てたときの図</p>
# </div>

# %% [markdown]
# 多項式$p(x, y) \in P$に$H$上の各点を代入することでパッチを表す$9$次元のベクトル$\boldsymbol{p} = [p_1, \cdots, p_9]^T$が得られる. &thinsp;$m(\boldsymbol{p}) := \frac{1}{9}\sum_{i}p_i \in \mathbb{R}$,&thinsp; $\vec{1} := [1, \cdots, 1]^T \in \mathbb{R}^9$とおき,&thinsp;写像$q: P \longrightarrow \mathbb{R}^9$を
# $$q(p):= \frac{\boldsymbol{p} - m(\boldsymbol{p})\vec{1}}{\|\boldsymbol{p} - m(\boldsymbol{p})\vec{1}\|}$$
# で定義する. &thinsp;$Im (q) \subset W := \{ \boldsymbol{x} \in \mathbb{R}^9 | \sum_{i}x_i = 0, \|\boldsymbol{x}\| = 1\}$であることに注意しよう.&thinsp; $W$は$S^7 \subset \mathbb{R}^8$と同相である. &thinsp;$W$を$S^7$と同一視して$q: P \longrightarrow S^7$とみなすことによって任意の多項式の族$T \subset P$を$S^7$の部分位相空間$Im(q|_T)$として扱うことができる.

# %% [markdown]
# ### &thinsp; パッチの高密度空間に対する結果
# $X := \{x_1 , \cdots, x_m \}\subset \mathbb{R}^N$を有限集合とする. &thinsp;$x \in X, k \in \mathbb{N}$に対して$\rho_k(x)$を,$x$から$k$番目に近い$X$の点との距離として定義する. &thinsp;誤解が無いよう式で書くと,&thinsp;集合 $\{ d(x, y) | y \in X \}$ を小さい順に番号づけして$\{d_1, \cdots, d_{m }\}$ としたときに $\rho_k(x) = d_k$ と定義する. &thinsp;
# $x \in X$の周辺の$X$の密度は$\rho_k(x)$に反比例する. &thinsp;
# $k$を固定したときに$\rho_k$は$X$上の関数となるが,&thinsp;このとき密度$1 / \rho_k$の上位$p \%$の$X$の点からなる集合を$X(k, p)$とする. &thinsp;下図は$X$が$m = 10$個の点からなる場合に$p = 80$としたときの$X(k, p)$を示したものである. &thinsp;

# %% [markdown]
# <div class = "pix-center">
#     <img src="images/X(k,p).jpeg" height = "50%" width = "50%" style="display: block; margin: auto;">
#     <p>$m = 10, p = 80$のときの$X(k,p)$の図</p>
# </div>

# %% [markdown]
# Carlssonは$X$をパッチの集合としたときの各$X(k, p)$のトポロジーの分析を行うにあたりパーシステントホモロジーを用いた. &thinsp;$k = 15, p = 30$に対する結果(Figure3)とパッチの空間の性質を考慮し,**three circle model $C_3$**(Figure4)が理に適っているものの一つとして提案している. &thinsp;

# %% [markdown]
# <div class = pix-center>
#    <img src="images/X(15,30).png" height = "70%" width = "70%">
#        <p>$k=15, p= 30$に対するパーシステントバーコード(carlsson [3] p. &thinsp;10 Figure7から転載)</p>
# </div>

# %% [markdown]
# <div class = pix-center>
#     <img src="images/C_3.jpeg" height = "70%" width = "70%">
#     <p>Three circle model (carlsson [3] p. &thinsp;8 Figure 5を一部修正したもの)</p>
# </div>

# %% [markdown]
# &emsp;$C_3$においては二つの円$S_v, S_h$は$S_{lin}$と$2$回交わっているが,&thinsp;互いには交点を持たないものであるとしてる. &thinsp;$C_3$はパッチ空間をクライン・ボトルによってパラメータ化した空間内に埋め込んで表現できる. &thinsp;Carlssonたちはパッチのデータセットに共通して強度が線形的なグラデーションをもち,&thinsp;水平方向と垂直方向に偏りがあることを発見した. &thinsp;カメラを45度に傾けて得られた写真のパッチの集まり($M$とは別のデータセット)に対しても同様に分析したところMumfordの基底$\boldsymbol{e}_1, \boldsymbol{e_2}$に射影されたパッチが$45$度傾いていたことも発見した. &thinsp;また$X(100, 10)$に対してパーシステントホモロジーを計算したところ,$1$次のベッチ数が$2$で$2$次のベッチ数が$1$であることが判明した. &thinsp;

# %% [markdown]
# <div class = pix-center>
#     <img src = "images/X(100, 10).png" height = "70%" width = "70%">
#      <p>$k = 100,p = 10$に対する結果(carlsson [3] p. &thinsp;11 Figure9から転載)</p>
# </div>

# %% [markdown]
# このホモロジーを持つ空間としては$2$次元トーラスとKlen bottleがあるが,[3]では$C_3$を含み,クライン・ボトルと同相な多項式の集合$K$を構成し,$K$の上では$q: P \longrightarrow S^7$が連続な単射である(つまり,クライン・ボトル同相な部分空間$im(q|_K)$を$S^7$が持つ)ことを証明した. &thinsp;$M$は$S^7$に射影されていることを思い出せば,$M$の高密度な部分集合ではクライン・ボトルが存在することを示している. &thinsp;

# %% [markdown]
# # &thinsp; 多様体上の点データに対するパーシステントホモロジー

# %% [markdown]
# &emsp;Carlssonたちは自然画像によるパッチの空間内にクライン・ボトルが存在することを証明した. &thinsp;一般に,&thinsp;ユークリッド空間内のあるデータの集合がある低次元多様体を近似していると考える仮説を**多様体仮説**というが,&thinsp;近似する多様体が$n$次元ホモロジー多様体であるなら,&thinsp;向きづけ可能なものとそうでないものに分類でき,$n$次のホモロジーは$\mathbb{Z}$係数では二種類しかない. &thinsp;そこで近似する多様体を求めるという視点ではなく,&thinsp;すでに知られている多様体上にデータの集合が散らばっていると考え,&thinsp;多様体を切り替えるごとに得られる特徴量をデータの特徴とみなす方法を考える. &thinsp;
# &emsp;似たような考えに基づいた統計学として,&thinsp;角度(方向)統計学がある. &thinsp;例えば地球上のある地点における風向きの観測データは角度のデータとして扱われるのだが,&thinsp;角度は$2\pi$の周期で同一視される特異性から通常の実数直線を標本空間として想定すると期待値や分散が不自然なものになる. &thinsp;これに対して方向統計学では角度データを統計的に正しく扱うために角度を円周上の$1$点と捉えた. &thinsp;つまり標本空間を$S^1$と捉えて期待値や分散を定義している. &thinsp;
# &emsp;角度データのように多様体の上にあると想定されたデータ集合上で脈体に基づく複体を用いたパーシステントホモロジーの計算を行う際も,&thinsp;ユークリッド空間上の点として通常の距離を用いるのは不自然と考えられる. &thinsp;そこでユークリッド空間上の点集合を多様体の点集合として捉える方法を述べる. &thinsp;

# %% [markdown]
# ## &thinsp; 多様体上の距離

# %% [markdown]
# &emsp;一般にリーマン多様体は距離空間としてみなすことができ,&thinsp;ナッシュの埋め込み定理によってすべてのリーマン多様体はあるユークリッド空間内へ等長に埋め込むことができる. &thinsp;したがって点データの集合に想定する多様体の位相と一致する距離を定義すれば,&thinsp;想定する多様体を得られたことになる. &thinsp;そこで以降はデータの集合と想定する多様体ごとに適切な距離を導入する. &thinsp;
# &emsp;なお,&thinsp;想定する$n$次元多様体$M$に対して,&thinsp;データ集合$D$が$D \subset \mathbb{R}^N( N > n)$なら,&thinsp;適当な次元削減$h:\mathbb{R}^N \longrightarrow \mathbb{R}^n $を行うことで,$h(D) \subset \mathbb{R}^k$をデータの集合として捉えることにする. &thinsp;そして,$h(D)$に$n$次元多様体$M$から定まる距離を計算し,$h(D)$を頂点とし,&thinsp;距離を重みとする重み付きグラフ$G(D)$を考える. &thinsp;この重み付きグラフから単体複体$\Delta(D)$を構成する. &thinsp;

# %% [markdown]
# ### &thinsp; 円周$S^1$

# %% [markdown]
# &emsp;まず$\mathbb{R}$から$S^1\subset \mathbb{R}^2$への連続写像$f:\mathbb{R} \longrightarrow S^1$として$f(x) = (\cos 2 \pi x,  \sin 2 \pi x)$を考える. &thinsp;
# その上で$\mathbb{R}$上に同値関係$\sim$を以下のように定めた商位相空間$\mathbb{R}/ \sim$を考える. &thinsp;
# $$a \sim b \overset{\text{def}}{\Longleftrightarrow} a - b \in \mathbb{Z}$$
# <!-- ここで$\pi : \mathbb{R} \longrightarrow \mathbb{R}/ \sim$を標準的射影とする. &thinsp;同値関係の定義から$\forall x \in \mathbb{R}$と$ 0 < \forall \epsilon < 1 / 2$に対して
# $$\pi^{-1}(\pi((x - \epsilon , x + \epsilon))) = \bigcup_{n \in \mathbb{Z}} (x + n  - \epsilon, x + n + \epsilon)$$
# が成り立つ. &thinsp;右辺は$\mathbb{R}$の開集合であるから$\pi((x - \epsilon , x + \epsilon))$は商空間$\mathbb{R}/\mathbb{Z}$の開集合となる. &thinsp;従って$\pi$は開写像となるから -->
# ここで
# $$a \sim b \Longleftrightarrow f(a) = f(b)$$
# が成り立つ. &thinsp;従って連続写像
# $$\hat f : \mathbb{R}/\sim \ni [x] \longmapsto f(x)  \in S^1$$
# が矛盾なく定義される. &thinsp;$\hat f$の逆写像として
# $$g : S^1 \ni  (\cos \theta, \sin \theta) ( 0 \leq \theta < 2\pi) \longmapsto  [\frac{\theta}{2 \pi}]  \in \mathbb{R}/ \sim $$
# が考えられるがこれもまた連続であることから$\hat f$は同相写像となる. &thinsp;そこで$\mathbb{R} \times \mathbb{R}$上の非負関数$d(x, y)$として次のように定義する. &thinsp;
# $$d_{S^1}(x, y) := \|f(x) - f(y) \|$$
# このとき
# $$d_{S^1}(x, y) = 0 \Longleftrightarrow x \sim y \\  x \sim x', y \sim y' \Longrightarrow d_{S^1}(x, y) = d_{S^1}(x', y') \\ d_{S^1}(x, y) = d_{S^1}(y, x) \\ d_{S^1}(x, y) \leq d_{S^1}(x, z) + d_{S^1}(z, y)$$
# となるから$d_{S^1}$は$\mathbb{R} / \sim$の商位相の距離関数となる. &thinsp;距離をこれで導入しても問題ないが,&thinsp;計算のしやすさという観点から,&thinsp;もう少し簡単な式に置き換えることにする. &thinsp;
# $d_{S^1}$は$d_{S^1}^2(x,y) = 2 - 2\cos 2 \pi |x - y|$となるから距離を計算する際は代わりに$1 - \cos 2\pi|x - y|$を計算してもよい. &thinsp;この関数は$z = |x - y|$とするとき,$0 \leq z \leq 1/2$で単調増加,$1/2 \leq z \leq 1$で単調減少,$z \in \{0, 1\} $のとき$0$になる関数であるから,&thinsp;距離の大小だけに注目するときは代わりに$1  - |2z - 1| $を計算すればよい. &thinsp;またこれは$2 \min(z, 1 -z)$と一致するため,&thinsp;最終的に
# $$d_{S^1}(x, y) = \min(|x -y|, 1 -|x - y|)$$
# として計算すればよい. &thinsp;

# %% [markdown]
# ### &thinsp; 実射影直線$P^1$
# $f:\mathbb{R} \longrightarrow S^1$を前節のものと同じとする. &thinsp;その上で$\mathbb{R}$上に同値関係$\sim '$を以下で定める. &thinsp;
# $$x \sim' y (x, y \in \mathbb{R}) \Longleftrightarrow f(x)  = f(y) \ \text{or} \ f(x) = - f(y)$$
# このとき
# $$x \sim' y  \Longleftrightarrow \ 2x - 2y \in \mathbb{Z}$$
# が成り立つ. &thinsp; そこで
# $$d_{P^1}(x, y) := \| f(2x) - f(2y) \|$$
# と定義すれば,&thinsp;これが商位相空間$\mathbb{R}/ \sim'$上の距離関数となる. &thinsp;$x \in \mathbb{R}$の同値な$y \in \mathbb{R}$は$y = x + n / 2 \ ( n \in \mathbb{Z})$の形で表されるから
# $$f(x + n/2) = (\cos (2\pi x + n\pi), \sin (2 \pi x + n \pi)) = \pm (\cos 2\pi x, \sin 2 \pi x) = \pm f(x)$$
# となるから写像
# $$\hat f: \mathbb{R}/\sim \ni [x] \longmapsto \{f(x), -f(x)\} \in P^{-1}$$
# が矛盾なく定義され,&thinsp;とくに同相写像となる. &thinsp;なお,$P^1$と$S^1$は位相的には同相となる. &thinsp;

# %% [markdown]
# ### &thinsp; $n$次元トーラス$T^n = S^1 \times \cdots \times S^1$

# %% [markdown]
# &emsp;各データ$p \in \mathbb{R}^n$を$n$次元トーラス$T^n$に埋め込む方法を考える. &thinsp; $T^n$は直積距離空間として捉えることができるため,$S^1$への埋め込みを用いて,$x = (x_1, \cdots, x_n), y = (y_1, \cdots, y_n) \in \mathbb{R}^n$に対して$d_{T^n}(x, y) := \sum_{i = 1}^{n} d_{S^1}(x_i,y_i)$として定義すればよい. &thinsp;

# %% [markdown]
# <div class = "pix-center">
# <img src = "images/Torus.png">
# <p>3次元空間内に表される2次元トーラス</p>
# </div>

# %% [markdown]
# ### &thinsp; クライン・ボトル
# &emsp;$I = [-1, 1]$の直積$I \times I$上のデータ$p \in I \times I$同士をクライン・ボトルの距離で計算する方法を与える. &thinsp;$I \times I$の点$p_1$はその属する象限に応じて$\mathbb{R}^2$内でFigure7のような同値な点をもつ. &thinsp;

# %% [markdown]
# <div class = pix-center>
#     <img src = "images/KleinBottleSamePoints.jpeg">
#      <p>クライン・ボトル内での$p_1$が第一象限のときの同値な4点を表している. &thinsp;</p>
#     <img src = "images/KleinBottle.png">
#     <p>3次元ユークリッド空間内で表現されたクライン・ボトルの図</p>
# </div>

# %% [markdown]
# そこで$p$に対してFigure7にあるような4点の集合を$C(p)$とするとき,クライン・ボトル上での距離関数を
# $$d_{Klein}(p, p') :=  \min \{d(x, x') | x \in C(p), x' \in C(p')\}$$
# で定義する. &thinsp;ここで$d(x, x')$は$2$次元のユークリッドの距離関数である. &thinsp;

# %% [markdown]
# ## &thinsp; いくつかの実験

# %% [markdown]
# &emsp;ここではいくつかのデータの集合$D$に対して,&thinsp;上記の距離を用いて実際にパーシステントホモロジーの計算を行なった結果を示す. &thinsp;具体的には$(X, d)$を距離空間として,$X$上の確率分布$P$からいくつかの乱数$D \subset X$を生成する. &thinsp;その後ヴィートリスリップス複体$VR_r(D)$によるパーシステントホモロジーの計算を行う. &thinsp;

# %% [markdown]
# ### &thinsp; 一様乱数
# $I = [-1, 1]$に対して,$X = I \times I$として,&thinsp;$500$個の一様乱数$D \subset X$を生成したときのパーシステントホモロジーの結果を$d = d_{Klein}, d_{T^2}$のときで示す. &thinsp;

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalKleinBarcode.png">
#     <p>$d_{Klein}$に対するパーシステントバーコード.<br>インターバルの長さが$0.1$より大きいもののみを表示している</p>
# </div>

# %% [markdown]
# <div class = pix-center>
# <img class = carlsson src="images/UniformalTorusBarcode.png" >
#  <p>$d_{T^2}$に対するパースシステントバーコード.<br>インターバルの長さが$0.2$より大きいもののみを表示している</p>
# </div>

# %% [markdown]
# クライン・ボトルもトーラスも$\mathbb{Z}_2$係数のホモロジーとしては同じものであるため二つのパーシステントバーコードはほぼ同じであるが,&thinsp;両方とも
# $$H_k(M) = \begin{cases} \mathbb{Z}_2  && k = 2, 0 \\ \mathbb{Z}_2 \oplus \mathbb{Z}_2 && k = 1 \\ \boldsymbol{0} && \text{else}\end{cases}$$
# のホモロジーがバーコード内で表れていることがわかる. &thinsp;クライン・ボトルは$1$次元のサイクルとしては,&thinsp;垂直方向と水平方向の二つを持つはずであるからそれらが誕生してから消滅するまでの過程を図示したのが以降の図である.
# &emsp; この図においては青が最も長く生存する生成元の代表サイクルであり,&thinsp;赤が2番目に長く生存する生成元の代表サイクルである. &thinsp;緑の部分は二つのサイクルの共通部分を表している. &thinsp; Interval ratioとはそれぞれの生成元の誕生時刻から消滅時刻まで数えて何%の時刻におけるサイクルなのかを表している.&thinsp; 例えばInterval ratioが$0$のときは誕生時刻におけるサイクルを表し,&thinsp; $0.5$のときは中間点,$0.9$は消滅する寸前の時刻を表している.&thinsp;　ただし,&thinsp;この図は二つの生成元の同時時刻における代表サイクルにはなっていないことに注意.

# %% [markdown]
# <div class = bold_text>
#     <p>クライン・ボトル の1次元サイクルの変化</p>
# </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalKleinCyclesAtBirth.png">
#     <p>クライン・ボトルにおける$1$次元ホモロジーの2つの生成元が誕生時時刻においてどのような代表サイクルを持つかを図示したもの. </p>
#  </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalKleinCyclesAtMiddle.png" >
#     <p>誕生時刻から消滅時刻の中間点におけるサイクル. 交差する部分が消えて,完全に垂直方向と水平方向の生成元に分けられる</p>
# </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalKleinCyclesAtEnd.png" >
#     <p>消滅する寸前におけるサイクル. &thinsp;赤のサイクルが一見複雑に見えるが,&thinsp;実際には垂直方向のサイクルである. &thinsp;</p>
# </div>

# %% [markdown]
# <div class =pix-center >
# <div class = bold-text>
#         <p>トーラス の1次元サイクルの変化</p>
# </div>
# </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalTorusCyclesAtBirth.png" >
#     <p>トーラスの場合における誕生時刻でのサイクル. &thinsp;<br>クライン・ボトルのときと比べても綺麗なサイクルになっていない</p>
# </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalTorusCyclesAtMiddle.png" >
#     <p>誕生時刻から消滅時刻の中間点におけるサイクル. &thinsp;<br>クライン・ボトルのときほど２方向に分類するのは難しい</p>
# </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/UniformalTorusCyclesAtEnd.png" >
#     <p>中間点における場合のときとほぼ変わらない</p>
# </div>

# %% [markdown]
# &emsp;クライン・ボトルの場合は水平方向の$1$次ホモロジーの生成元がパーシステントホイットニー類に対応するから,&thinsp;微々たる差ではあるがこの例ではインターバルが最も長いサイクルがパーシステントホイットニー類となる. &thinsp;
# &emsp;一様乱数の場合は水平方向と垂直方向のサイクルのインターバルの長さはほぼ同じだったが,&thinsp;データが片方に偏りを持つ場合は顕著に違いが現れるはずである. &thinsp;そこで次はデータが2次元正規分布に従う場合を示す. &thinsp;

# %% [markdown]
# ### &thinsp; 正規分布の場合

# %% [markdown]
# &emsp;正規分布は2次元平面上の確率分布であるため次のような確率分布として変換する. &thinsp;まず$f(x;\mu, \sigma^2)$を$1$次元正規分布の確率密度関数とする. &thinsp;今$P(-1 \leq x \leq 1) = \int_{-1}^{1} f(x; \mu, \sigma^2) dx$とするとき,$[a, b]$上の確率密度関数を
# $$\hat f(x; \mu, \sigma^2) := \frac {f(x; \mu, \sigma^2)}{P(-1 \leq x \leq 1)}  \ \ x \in [-1, 1]$$
# とする. &thinsp;そして$I \times I$上の確率密度関数$g(x, y)$として,&thinsp;二つの$\hat f(x; \mu_1, \sigma_1^2), \hat f(x; \mu_2, \sigma_2^2)$の同時確率密度関数
# $$g(x, y) := \hat f(x; \mu_1, \sigma_1^2)\hat f(y; \mu_2, \sigma_2^2)$$
# によって定義する. &thinsp;

# %% [markdown]
# &emsp;以下では$\mu_1 = \mu_2 = 0, \sigma_1 = 0.5, \sigma_2 = 0.3$として$500$個の乱数を生成したときに,クライン・ボトルの距離でヴィートリス・リップス複体のパーシステントホモロジーを計算した結果を示す. &thinsp;

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/NormalKleinBarcode.png">
#     <p>一様乱数の時と同様にインターバルの長い$1$次元の生成元が二つ生まれている. &thinsp;<br>なおインターバルの長さが$0.1$より大きいもののみを表示している. &thinsp;</p>
#  </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/NormalKleinCyclesAtBirth.png">
#     <p>二つの生成元の誕生時刻における代表サイクル. &thinsp;水平方向の方が垂直方向よりインターバルが長い</p>
#  </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/NormalKleinCyclesAtMiddle.png">
#     <p>誕生から生滅までの中間点における代表サイクル</p>
#  </div>

# %% [markdown]
# <div class = pix-center>
#     <img class = carlsson src="images/NormalKleinCyclesAtEnd.png">
#     <p>生滅する寸前のときの代表サイクル</p>
#  </div>

# %% [markdown]
# &emsp;乱数は$x$方向の方に分散を大きくとったため,$1$次元ホモロジーでは水平方向の生成元が最もインターバルが長いものになるはずであり,&thinsp;実際にバーコードと代表サイクルの図からそうなっていることがわかる. &thinsp;従ってパーシステントホイットニー類は$H_1$バーコード内の最も長いインターバルに対応する. &thinsp;

# %% [markdown]
# # &thinsp; まとめ
# &emsp;　本修士論文では多様体上の点データクラウドに対するパーシステントホモロジーと,&thinsp; パーシステントホイットニー類について定義した.&thinsp; またそれらを一様乱数などの人工データを用いて,&thinsp; 実際に計算されるホモロジーとホイットニー類についても観察した. &thinsp; 本来ならCarlsson らの研究で使用されたデータに対して計算機実験を行いたかったが,&thinsp; そこまでに至ることはできなかった. &thinsp; 方向統計学などでは円周やトーラス上の確率分布がいくつか提示されていたため, &thinsp; クライン・ボトル上での確率分布の考察や実データを用いた実験は今後の課題にしたい.
# <!-- &emsp;この論文では多様上にプロットされた点群に対するパーシステントホモロジーとパーシステントホイットニー類について論じた。主にクライン・ボトルやTorusなどの$2$次元ホモロジー多様体に限ったが,&thinsp;直積空間をとることでより高次元なデータに対しても計算は行える. &thinsp;点データのサンプルとしては$I \times I$上の確率分布$P$に従う乱数$x$を発生させた後,&thinsp;全射$\pi: I \times I \longrightarrow  M = I \times I /\sim$によって$\pi((x, y)) = [(x, y)]$を得ることで,&thinsp;多様体$M$内のランダムな要素を発生させたことになる. &thinsp;ただし,$M$の集合$B \subset M$に対して,$\pi(x) \in B$となる確率は$x \in \pi^{-1}(B)$と同等であるから,$M$内からランダムな要素を発生させるプロセスは,&thinsp;実際には$M$の確率分布を -->
# <!-- <!-- 抽象化すると,$\mathbb{R}^2$を標本空間,$\mathcal{F}$をボレル集合族,$P$を確率測度とする確率空間$(\mathbb{R}^2, \mathcal{F}, P)$と標準的な全射$\pi: \mathbb{R}^2 \longrightarrow \mathbb{R}^2/\sim$に対して$\mathbb{R}^2/\sim$上に確率空間$(\mathbb{R}^2/\sim, \mathcal{F}_{\pi}, P_{\pi})$を -->
# <!-- $$P_{\pi}(B) :=  P( \pi^{-1} (B))$$
# と定義したことと同等になる. &thinsp;$M$上に確率分布を定義するという視点に立つと,$M$を得るための閉区間としては一般の閉区間$[a, b] \times [c, d]$に拡張することができ,&thinsp;同様な方法で$M$上の確率分布を得る方法もある. &thinsp;また本来ならもとの点データが$\mathbb{R}^2$内のものであるなら,&thinsp;同値関係を$\mathbb{R}$に拡張してから$M$上の確率分布を得るのが好ましい. &thinsp;しかし,&thinsp;これらが本当に$M$上の分布として自然なものなのかの疑問は残る. &thinsp;実際に角度統計学では正規分布の$S^1$版としてフォン・ミューゼス分布と呼ばれるものを定義している. &thinsp;多様体$M$,&thinsp;特にクライン・ボトル上に定まる自然な確率分布に関する考察は今後の課題とする. &thinsp;また,&thinsp;実験の方法としては$M$上に人工的な確率分布を定めて計算を行ったが,Carlssonたちの研究で用いられたデータセットを使って実際にクライン・ボトルのパーシステントホモロジーを使用した分析を行いたかったが,&thinsp;想像以上に理論的な整備を整える必要があり,&thinsp;十分な時間を取ることができなかった. &thinsp; -->

# %% [markdown]
# # 参考文献
# [1] D. &thinsp; Mumford, A. &thinsp; Lee, and K. &thinsp; Pedersen, “The nonlinear statistics of high-contrast patches in
# natural images,” Intl. &thinsp; J. &thinsp; Computer Vision, Vol. &thinsp; 54 (2003). &thinsp;
# [2]Carlsson G. &thinsp;, de Silva V. &thinsp; Topological estimation using witness complexes. &thinsp; Symposium on Point-
# Based Graphics (2004)
# [3] G. &thinsp; Carlsson, T. &thinsp; Ishkhanov, V. &thinsp; de Silva, and A. &thinsp; Zomorodian, “On the local behavior of spaces
# of natural images,” preprint, (2006). &thinsp;
# [4] R. &thinsp;Ghrist, "Barcodes: The persistent topology of data"
# [5] 田村一郎 (2015)「トポロジー」 岩波オンデマンドブックス
# [6] 清水邦夫 (2018)「角度データのモデリング」(ISMシリーズ:進化する統計数理7) 近代科学社
# [7] J. &thinsp;Wミルナー, J. &thinsp;Dスタシェフ (2017)「特性類講義」(シュプリンガー数学クラシックス) (佐伯修・佐久間一浩訳) 丸善出版
# [8] Loring W. &thinsp;Tu (2019)「トゥー多様体:An Introduction to Manifolds」(枡田幹也・阿部拓・堀口達也 訳) 裳華房
# [9]  Dimitry Kozlov (2008)「Combinatorial Algebraic Topology : Algorithms and Computation in Mathematics」Springer
